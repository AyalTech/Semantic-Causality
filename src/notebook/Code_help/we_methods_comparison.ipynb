# %%
# DO NOT DELETE!
# Evaluate word embeddings on different dimension numbers
# ------
#import nltk
#nltk.data.path.insert(0, "/home/saffeldt/Projects/Projects_we/source/we_ensemble/data/nltk_data")
#nltk.download('brown', download_dir = "/home/saffeldt/Projects/Projects_we/source/we_ensemble/data/nltk_data")
#print(nltk.data.path)
#print(nltk.corpus.brown.words())

# %%
# DO NOT DELETE!
## Preprocess Brown corpus
#from gensim.parsing.preprocessing import strip_punctuation, strip_multiple_whitespaces
#import os
#import zipfile
#import wget
#
## Generate brown corpus text file
#if not os.path.isfile('../data/nltk_data/brown_corp.txt'):
#    with open('../data/nltk_data/brown_corp.txt', 'w+') as f:
#        print(os.path.realpath(f.name))
#        for word in nltk.corpus.brown.words():
#            f.write('{word} '.format(word = word))
#        f.seek(0)
#        brown = f.read()
#
## Preprocess brown corpus
#if not os.path.isfile('../data/nltk_data/proc_brown_corp.txt'):
#    with open('../data/nltk_data/proc_brown_corp.txt', 'w') as f:
#        proc_brown = strip_punctuation(brown)
#        proc_brown = strip_multiple_whitespaces(proc_brown).lower()
#        f.write(proc_brown)

# %%
import os

# Download the text8 corpus (a 100 MB sample of preprocessed 
# wikipedia text)
if not os.path.isfile('../data/text8'):
    #!wget -c http://mattmahoney.net/dc/text8.zip
    wget.download('http://mattmahoney.net/dc/text8.zip', 
                  '../data/text8.zip')
    #!unzip text8.zip
    archive = zipfile.ZipFile('../data/text8.zip')
    archive.extractall('../data/')

# %%
# Set WR_HOME et FT_HOME to respective directory root
#FT_HOME = '../fastText/'

# Train models
# ------
from gensim.models import Word2Vec
from gensim.models.fasttext import FastText
from gensim.models import KeyedVectors
from gensim.models.word2vec import Text8Corpus
import os
import itertools
from glove import Corpus, Glove

lr = 0.025
window = 5
nbThreads = 3
minCount = 50
t = 0
n_iter = 10

# word2vec
w2v_params = {
    'alpha': lr,
    'window': window,
    'iter': n_iter, # Nbr epochs
    'min_count': minCount,
    'sample': t,
    'sg': 1,
    'hs': 0,
    'negative': 5
}

# fasttext
ft_params = {
    'alpha': lr,
    'window': window,
    'iter': n_iter, # Nbr epochs
    'min_count': minCount,
    'sample': t,
    'sg': 1,
    'hs': 0,
    'negative': 5
}

# Glove parameters
gv_lr = lr
gv_window = window

MODELS_DIR = '../data/models/'
# !mkdir -p {MODELS_DIR}

def train_w2v(corpus_file, output_name, dim):
    
    # Train using word2vec
    output_file = '{:s}_wv'.format(output_name)
    if not os.path.isfile(os.path.join(MODELS_DIR, '{:s}{:d}dim.vec'.format(output_file, dim))):
        print('\nTraining word2vec on {:s} corpus..'.format(corpus_file))
        # Text8Corpus class for reading space-separated words file
        # %time wv_model = Word2Vec(Text8Corpus(corpus_file), size = dim, **w2v_params); wv_model
        locals()['wv_model'].wv.save_word2vec_format(os.path.join(MODELS_DIR, 
                                                                  '{:s}{:d}dim.vec'.format(output_file, dim)))
        print('\nSaved word2vec model as {:s}{:d}dim.vec'.format(output_file, dim))
    else:
        print('\nUsing existing model file {:s}{:d}dim.vec'.format(output_file, dim))

def train_ft(corpus_file, output_name, dim):
    
    # Train using fasttext
    #output_file = '{:s}_ft'.format(output_name)
    #if not os.path.isfile(os.path.join(MODELS_DIR, '{:s}{:d}dim.vec'.format(output_file, dim))):
    #    print('\nTraining fasttest on {:s} corpus..'.format(corpus_file))
    #    #%time !{FT_HOME}fasttext skipgram -input {corpus_file} -output {MODELS_DIR+output_file} -lr {lr} -dim {dim} -ws {ws} -epoch {epoch} -minCount {minCount} -neg {neg} -loss {loss} -t {t}
    #    tmp_output_file = os.path.join(MODELS_DIR, '{:s}{:d}dim'.format(output_file, dim))
    #    %time !{FT_HOME}fasttext skipgram -input {corpus_file} -output {tmp_output_file} -lr {lr} -dim {dim} -ws {ws} -epoch {ft_iter} -minCount {minCount} -neg {neg} -loss {loss} -t {t}
    #    print('\nSaved fasttext model as {:s}{:d}dim.vec'.format(output_file, dim))
    #else:
    #    print('\nUsing existing model file {:s}{:d}dim.vec'.format(output_file, dim))
        
    output_file = '{:s}_ft'.format(output_name)
    if not os.path.isfile(os.path.join(MODELS_DIR, '{:s}{:d}dim.vec'.format(output_file, dim))):
        print('\nTraining fasttest on {:s} corpus..'.format(corpus_file))
        # Text8Corpus class for reading space-separated words file
        # %time ft_model = FastText(sentences = Text8Corpus(corpus_file), size = dim, **ft_params); ft_model
        
        locals()['ft_model'].wv.save_word2vec_format(os.path.join(MODELS_DIR, 
                                                                  '{:s}{:d}dim.vec'.format(output_file, dim)))
        print('\nSaved fasttext model as {:s}{:d}dim.vec'.format(output_file, dim))
    else:
        print('\nUsing existing model file {:s}{:d}dim.vec'.format(output_file, dim))
        
    

def train_gv(corpus, corpus_file, output_name, dim):
    
    # Train using GloVe
    output_file = '{:s}_gv'.format(output_name)
    if not os.path.isfile(os.path.join(MODELS_DIR, '{:s}{:d}dim.vec'.format(output_file, dim))):
        print('\nTraining GloVe on {:s} corpus..'.format(corpus_file))
        glove = Glove(no_components = dim, learning_rate = gv_lr)
        glove.fit(corpus.matrix, epochs = n_iter, no_threads = nbThreads, verbose = True)
        glove.add_dictionary(corpus.dictionary)

        # Sort words by their id
        word_and_word_id_tuples = list(glove.dictionary.items())
        word_and_word_id_tuples.sort(key=lambda t: t[1])  # id is second element of tuple

        # Save vectors to output file
        with open(os.path.join(MODELS_DIR, '{:s}{:d}dim.vec'.format(output_file, dim)), 'w+') as f:
            f.write(str(len(word_and_word_id_tuples)) + " " + str(dim) + "\n")
            for word, word_id in word_and_word_id_tuples:
                f.write(word + " " + " ".join([str(value) for value in glove.word_vectors[word_id]]) + "\n")

        print('\nSaved GloVe model as {:s}{:d}dim'.format(output_file, dim))
    else:
        print('\nUsing existing model file {:s}{:d}dim'.format(output_file, dim))

# %%
# Prepare the corpus variable for GloVe
corpus = dict()
sentences = dict()
## Brown
#corpus_file = '../data/nltk_data/proc_brown_corp.txt'
#corpus_name = 'brown'
#sentences[corpus_name] = list(itertools.islice(Text8Corpus(corpus_file),None))
#corpus[corpus_name]= Corpus()
#corpus[corpus_name].fit(sentences[corpus_name], window = window)

# Text8
#corpus_file = '../data/text8'
corpus_file = '../data/proc_text8_corp_clean.txt'
corpus_name = 'text8'
sentences[corpus_name] = list(itertools.islice(Text8Corpus(corpus_file), None))
corpus[corpus_name] = Corpus()
corpus[corpus_name].fit(sentences[corpus_name], window = gv_window)

# %%
type(corpus[corpus_name].dictionary)

len(dict(list(zip(all_models['100'].index2word, range(len(all_models['100'].index2word))))))
# Out:
# dict

# %%
#for dim in [50, 100, 150, 200, 250]:
for dim in [100, 150, 200, 250]:    
    ## Train word2vec, fast text, GloVe on Brown
    #corpus_file = '../data/nltk_data/proc_brown_corp.txt'
    #corpus_name = 'brown'
    #train_w2v(corpus_file = corpus_file, output_name = corpus_name, dim = dim)
    #train_ft(corpus_file = corpus_file, output_name = corpus_name, dim = dim)
    #train_gv(corpus = corpus[corpus_name], corpus_file = corpus_file, output_name = corpus_name, dim = dim)
        
    # Train word2vec, fast text, GloVe on Text8
    #corpus_file = '../data/text8'
    corpus_file = '../data/proc_text8_corp_clean.txt'
    corpus_name = 'text8'
    train_w2v(corpus_file = corpus_file, output_name = corpus_name, dim = dim)
    train_ft(corpus_file = corpus_file, output_name = corpus_name, dim = dim)
    train_gv(corpus = corpus[corpus_name], corpus_file = corpus_file, output_name = corpus_name, dim = dim)
# Out:
# 2019-02-05 00:28:56,483 : INFO : collecting all words and their counts
# 2019-02-05 00:28:56,489 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# Training word2vec on ../data/proc_text8_corp_clean.txt corpus..
# 2019-02-05 00:28:58,777 : INFO : collected 252830 word types from a corpus of 8550600 raw words and 856 sentences
# 2019-02-05 00:28:58,778 : INFO : Loading a fresh vocabulary
# 2019-02-05 00:28:58,880 : INFO : effective_min_count=50 retains 17839 unique words (7% of original 252830, drops 234991)
# 2019-02-05 00:28:58,881 : INFO : effective_min_count=50 leaves 7491160 word corpus (87% of original 8550600, drops 1059440)
# 2019-02-05 00:28:58,925 : INFO : deleting the raw counts dictionary of 252830 items
# 2019-02-05 00:28:58,932 : INFO : sample=0 downsamples 0 most-common words
# 2019-02-05 00:28:58,933 : INFO : downsampling leaves estimated 7491160 word corpus (100.0% of prior 7491160)
# 2019-02-05 00:28:59,000 : INFO : estimated required memory for 17839 words and 100 dimensions: 23190700 bytes
# 2019-02-05 00:28:59,002 : INFO : resetting layer weights
# 2019-02-05 00:28:59,174 : INFO : training model with 3 workers on 17839 vocabulary and 100 features, using sg=1 hs=0 sample=0 negative=5 window=5
# 2019-02-05 00:29:00,209 : INFO : EPOCH 1 - PROGRESS: at 5.72% examples, 413415 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:29:01,238 : INFO : EPOCH 1 - PROGRESS: at 11.68% examples, 420914 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:29:02,260 : INFO : EPOCH 1 - PROGRESS: at 18.34% examples, 444612 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:29:03,270 : INFO : EPOCH 1 - PROGRESS: at 25.00% examples, 457934 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:29:04,272 : INFO : EPOCH 1 - PROGRESS: at 31.31% examples, 460677 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:29:05,288 : INFO : EPOCH 1 - PROGRESS: at 36.45% examples, 447265 words/s, in_qsize 4, out_qsize 1
# 2019-02-05 00:29:06,321 : INFO : EPOCH 1 - PROGRESS: at 42.29% examples, 443750 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:29
words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:31:58,506 : INFO : EPOCH 9 - PROGRESS: at 79.67% examples, 368261 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:31:59,536 : INFO : EPOCH 9 - PROGRESS: at 84.70% examples, 368119 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:00,587 : INFO : EPOCH 9 - PROGRESS: at 89.95% examples, 368282 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:01,596 : INFO : EPOCH 9 - PROGRESS: at 95.09% examples, 369162 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:32:02,501 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-05 00:32:02,543 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-05 00:32:02,559 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-05 00:32:02,560 : INFO : EPOCH - 9 : training on 8550600 raw words (7491160 effective words) took 20.3s, 369270 effective words/s
# 2019-02-05 00:32:03,600 : INFO : EPOCH 10 - PROGRESS: at 5.02% examples, 361991 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:04,605 : INFO : EPOCH 10 - PROGRESS: at 10.16% examples, 370509 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:32:05,619 : INFO : EPOCH 10 - PROGRESS: at 15.19% examples, 370438 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:32:06,635 : INFO : EPOCH 10 - PROGRESS: at 20.21% examples, 370855 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:32:07,636 : INFO : EPOCH 10 - PROGRESS: at 25.35% examples, 374652 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:32:08,641 : INFO : EPOCH 10 - PROGRESS: at 30.02% examples, 370521 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:09,694 : INFO : EPOCH 10 - PROGRESS: at 35.28% examples, 370908 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:32:10,745 : INFO : EPOCH 10 - PROGRESS: at 40.19% examples, 368235 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:11,781 : INFO : EPOCH 10 - PROGRESS: at 45.09% examples, 366898 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:12,789 : INFO : EPOCH 10 - PROGRESS: at 49.88% examples, 365700 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:13,795 : INFO : EPOCH 10 - PROGRESS: at 54.44% examples, 363098 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:14,816 : INFO : EPOCH 10 - PROGRESS: at 59.46% examples, 363730 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:32:15,862 : INFO : EPOCH 10 - PROGRESS: at 64.49% examples, 363534 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:32:16,867 : INFO : EPOCH 10 - PROGRESS: at 69.51% examples, 364382 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:17,871 : INFO : EPOCH 10 - PROGRESS: at 74.53% examples, 365396 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:18,901 : INFO : EPOCH 10 - PROGRESS: at 79.56% examples, 365312 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 00:32:19,951 : INFO : EPOCH 10 - PROGRESS: at 84.81% examples, 365926 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:20,984 : INFO : EPOCH 10 - PROGRESS: at 90.07% examples, 366598 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:21,999 : INFO : EPOCH 10 - PROGRESS: at 95.21% examples, 367425 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 00:32:22,895 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-05 00:32:22,908 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-05 00:32:22,951 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-05 00:32:22,952 : INFO : EPOCH - 10 : training on 8550600 raw words (7491160 effective words) took 20.4s, 367386 effective words/s
# 2019-02-05 00:32:22,953 : INFO : training on a 85506000 raw words (74911600 effective words) took 203.8s, 367614 effective words/s
# 2019-02-05 00:32:22,953 : INFO : storing 17839x100 projection weights into ../data/models/text8_wv100dim.vec
# CPU times: user 10min 17s, sys: 1.33 s, total: 10min 19s
# Wall time: 3min 26s
# 2019-02-05 00:32:24,041 : INFO : collecting all words and their counts
# 2019-02-05 00:32:24,042 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# Saved word2vec model as text8_wv100dim.vec
#
# Training fasttest on ../data/proc_text8_corp_clean.txt corpus..
# 2019-02-05 00:32:26,549 : INFO : collected 252830 word types from a corpus of 8550600 raw words and 856 sentences
# 2019-02-05 00:32:26,549 : INFO : Loading a fresh vocabulary
# 2019-02-05 00:32:26,640 : INFO : effective_min_count=50 retains 17839 unique words (7% of original 252830, drops 234991)
words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:19,272 : INFO : EPOCH 10 - PROGRESS: at 80.49% examples, 99253 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:20,287 : INFO : EPOCH 10 - PROGRESS: at 81.89% examples, 99282 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:21,322 : INFO : EPOCH 10 - PROGRESS: at 83.29% examples, 99298 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:22,406 : INFO : EPOCH 10 - PROGRESS: at 84.70% examples, 99302 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:23,441 : INFO : EPOCH 10 - PROGRESS: at 86.10% examples, 99322 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:24,524 : INFO : EPOCH 10 - PROGRESS: at 87.62% examples, 99377 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:25,553 : INFO : EPOCH 10 - PROGRESS: at 89.02% examples, 99402 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:26,612 : INFO : EPOCH 10 - PROGRESS: at 90.42% examples, 99410 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:27,613 : INFO : EPOCH 10 - PROGRESS: at 91.71% examples, 99402 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 01:42:28,662 : INFO : EPOCH 10 - PROGRESS: at 93.11% examples, 99414 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:29,712 : INFO : EPOCH 10 - PROGRESS: at 94.51% examples, 99438 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:30,756 : INFO : EPOCH 10 - PROGRESS: at 95.91% examples, 99449 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:31,794 : INFO : EPOCH 10 - PROGRESS: at 97.31% examples, 99472 words/s, in_qsize 6, out_qsize 0
# 2019-02-05 01:42:32,829 : INFO : EPOCH 10 - PROGRESS: at 98.71% examples, 99484 words/s, in_qsize 5, out_qsize 0
# 2019-02-05 01:42:33,502 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-02-05 01:42:33,606 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-02-05 01:42:33,660 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-02-05 01:42:33,660 : INFO : EPOCH - 10 : training on 8550600 raw words (7491160 effective words) took 75.2s, 99553 effective words/s
# 2019-02-05 01:42:33,661 : INFO : training on a 85506000 raw words (74911600 effective words) took 752.9s, 99499 effective words/s
# 2019-02-05 01:42:34,444 : INFO : storing 17839x250 projection weights into ../data/models/text8_ft250dim.vec
# CPU times: user 37min 47s, sys: 2.17 s, total: 37min 49s
# Wall time: 12min 37s
#
# Saved fasttext model as text8_ft250dim.vec
#
# Training GloVe on ../data/proc_text8_corp_clean.txt corpus..
# Performing 10 training epochs with 3 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
#
# Saved GloVe model as text8_gv250dim

# %%
# Evaluate models
# ------
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',
                   level = logging.INFO)

# wordsim_sim
wordsim_sim_file = "../eval_files/wordsim_similarity_goldstandard.txt"
# wordsim_rel
wordsim_rel_file = "../eval_files/wordsim_relatedness_goldstandard.txt"
# wordsim_353
wordsim_file = "../eval_files/wordsim353.tsv"
# men
men_file = "../eval_files/MEN_dataset_natural_form_full.tsv"
# mturk
mturk_file = "../eval_files/mturk-771.tsv"
# simlex
simlex_file = "../eval_files/simlex999.txt"
# analogy
word_analogies_file = "../eval_files/questions-words.txt"

def print_analogy_accuracy(model, questions_file):
    acc = model.evaluate_word_analogies(questions_file, 
                                        dummy4unknown=False)
    
    # Semantic:
    # [0] capital-common-countries, [1] capital-world
    # [2] currency, [3] city-in-state, [4] family
    n_sem = 5
    sem_correct = sum((len(acc[1][i]['correct']) for i in range(n_sem)))
    sem_total = sum((len(acc[1][i]['correct']) + len(acc[1][i]['incorrect'])) for i in range(n_sem))
    sem_acc = 100*float(sem_correct)/sem_total
    print('\nSemantic: {:d}/{:d}, Accuracy: {:.2f}%'.format(sem_correct, sem_total, sem_acc))
    
    # Syntactic:
    # [5] gram1-adjective-to-adverb, [6] gram2-opposite, [7] gram3-comparative,
    # [8] gram4-superlative, [9] gram5-present-participle, [10] gram6-nationality-adjective,
    # [11] gram7-past-tense, [12] gram8-plural, [13] gram9-plural-verbs
    syn_correct = sum((len(acc[1][i]['correct']) for i in range(n_sem, len(acc[1])-1)))
    syn_total = sum((len(acc[1][i]['correct']) + len(acc[1][i]['incorrect'])) for i in range(n_sem,len(acc[1])-1))
    syn_acc = 100*float(syn_correct)/syn_total
    print('Syntactic: {:d}/{:d}, Accuracy: {:.2f}%\n'.format(syn_correct, syn_total, syn_acc))
    
    return sem_acc, syn_acc
    
def print_similarity_accuracy(model, similarity_file):
    acc = model.evaluate_word_pairs(similarity_file, dummy4unknown=False)
    #print('Pearson correlation coefficient: {:.2f}'.format(acc[0][0]))
    print('Spearman rank correlation coefficient: {:.2f}'.format(acc[1][0]))
    
    #return acc[0][0], acc[1][0]
    return acc[1][0]

# %%
# DO NOT DELETE !!!!

## Load and evaluate the Word2Vec embeddings
#print('\nLoading Gensim embeddings')
#brown_wv = KeyedVectors.load_word2vec_format(MODELS_DIR + 'brown_wv.vec')
#
## Brown: Explore the Word2Vec embeddings
#
## get the word vector of "the"
##brown_wv['the']
#
## get the most common words
#print(brown_wv.index2word[0], 
#      brown_wv.index2word[1], 
#      brown_wv.index2word[2])
#
## get the least common words
#vocab_size = len(brown_wv.vocab)
#print(vocab_size)
#print(brown_wv.index2word[vocab_size - 1], 
#      brown_wv.index2word[vocab_size - 2], 
#      brown_wv.index2word[vocab_size - 3])
#
## find the index of the 2nd most common word ("of")
#print('Index of "of" is: {}'.format(brown_wv.vocab['of'].index))
#
## some similarity fun
#print(brown_wv.similarity('woman', 'man'), 
#      brown_wv.similarity('man', 'elephant'))
#
## what doesn't fit?
#print(brown_wv.doesnt_match("green blue red zebra".split()))
#
#import numpy as np
## convert the word vectors into a numpy matrix that is 
## suitable for insertion into our TensorFlow and Keras models
#embedding_matrix_brown_wv = np.zeros((vocab_size, vector_dim))
#for i in range(vocab_size):
#    embedding_vector = brown_wv[brown_wv.index2word[i]]
#    if embedding_vector is not None:
#        embedding_matrix_brown_wv[i] = embedding_vector
#print(embedding_matrix_brown_wv.shape)

# %%
def we_evaluation(output_name, method, dim):
    
    output_file = '{:s}_{:s}'.format(output_name, method)
    
    print('\nLoading {:s} embeddings (dim = {:d}, meth = {:s})'.format(output_name, dim, method))
    tmp_model = KeyedVectors.load_word2vec_format(MODELS_DIR + '{:s}{:d}dim.vec'.format(output_file, dim))

    tmp_eval = list()
    print("\nWordSim-353 similarity")
    ret_corSpearman_word_sim = print_similarity_accuracy(tmp_model, wordsim_sim_file)
    tmp_eval.append(ret_corSpearman_word_sim)
    print("\nWordSim-353 relatedness")
    ret_corSpearman_word_rel = print_similarity_accuracy(tmp_model, wordsim_rel_file)
    tmp_eval.append(ret_corSpearman_word_rel)
    print("\nWordSim-353")
    ret_corSpearman_word = print_similarity_accuracy(tmp_model, wordsim_file)
    tmp_eval.append(ret_corSpearman_word)
    print("\nMEN similarity")
    ret_corSpearman_men = print_similarity_accuracy(tmp_model, men_file)
    tmp_eval.append(ret_corSpearman_men)
    print("\nMturk similarity")
    ret_corSpearman_men = print_similarity_accuracy(tmp_model, mturk_file)
    tmp_eval.append(ret_corSpearman_men)
    print('SimLex-999 similarity')
    ret_corSpearman_simlex = print_similarity_accuracy(tmp_model, simlex_file)
    tmp_eval.append(ret_corSpearman_simlex)
    print('Accuracy:')
    ret_sem_acc, ret_syn_acc = print_analogy_accuracy(tmp_model, word_analogies_file)
    tmp_eval.append(ret_sem_acc)
    tmp_eval.append(ret_syn_acc)
    
    return tmp_eval
  
eval_all = dict()

#for cp_name in ['brown', 'text8']:
for cp_name in ['text8']:
    output_name = cp_name
    eval_all[cp_name] = list()
    
    # Load and evaluate the Word2Vec embeddings
    for dim in [50, 100, 150, 200, 250]:
    #for dim in [50]:

        # Load and evaluate the Word2Vec embeddings
        method = 'wv'
        ret_eval = we_evaluation(output_name, method, dim)
        eval_all[cp_name].append(ret_eval)

        # Load and evaluate the FastText embeddings
        method = 'ft'
        ret_eval = we_evaluation(output_name, method, dim)
        eval_all[cp_name].append(ret_eval)

        # Load and evaluate the FastText embeddings
        method = 'gv'
        ret_eval = we_evaluation(output_name, method, dim)
        eval_all[cp_name].append(ret_eval)
    
print(eval_all)
# Out:
# 2019-02-05 10:58:12,090 : INFO : loading projection weights from ../data/models/text8_wv50dim.vec
# Loading text8 embeddings (dim = 50, meth = wv)
# 2019-02-05 10:58:12,915 : INFO : loaded (17839, 50) matrix from ../data/models/text8_wv50dim.vec
# 2019-02-05 10:58:12,927 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7466
# 2019-02-05 10:58:12,927 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7348
# 2019-02-05 10:58:12,928 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 10:58:12,948 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6290
# 2019-02-05 10:58:12,949 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6440
# 2019-02-05 10:58:12,949 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 10:58:12,978 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6787
# 2019-02-05 10:58:12,979 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.6955
# 2019-02-05 10:58:12,979 : INFO : Pairs with unknown words ratio: 15.0%
# 2019-02-05 10:58:13,067 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.6850
# 2019-02-05 10:58:13,068 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.6829
# 2019-02-05 10:58:13,068 : INFO : Pairs with unknown words ratio: 29.8%
# 2019-02-05 10:58:13,100 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5590
# 2019-02-05 10:58:13,100 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.5615
# 2019-02-05 10:58:13,101 : INFO : Pairs with unknown words ratio: 12.7%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.73
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.64
#
# WordSim-353
# Spearman rank correlation coefficient: 0.70
#
# MEN similarity
# Spearman rank correlation coefficient: 0.68
#
# Mturk similarity
# Spearman rank correlation coefficient: 0.56
# SimLex-999 similarity
# 2019-02-05 10:58:13,293 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.2903
# 2019-02-05 10:58:13,294 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.2633
# 2019-02-05 10:58:13,294 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 10:58:13,303 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 10:58:13,304 : INFO : precomputing L2-norms of word weight vectors
# 2019-02-05 10:58:13,451 : INFO : capital-common-countries: 58.5% (200/342)
# Spearman rank correlation coefficient: 0.26
# Accuracy:
# 2019-02-05 10:58:13,731 : INFO : capital-world: 48.7% (343/704)
# 2019-02-05 10:58:13,785 : INFO : currency: 17.9% (19/106)
# 2019-02-05 10:58:14,109 : INFO : city-in-state: 21.5% (207/963)
# 2019-02-05 10:58:14,193 : INFO : family: 42.4% (89/210)
# 2019-02-05 10:58:14,364 : INFO : gram1-adjective-to-adverb: 23.2% (107/462)
# 2019-02-05 10:58:14,437 : INFO : gram2-opposite: 16.7% (26/156)
# 2019-02-05 10:58:14,750 : INFO : gram3-comparative: 40.2% (399/992)
# 2019-02-05 10:58:14,887 : INFO : gram4-superlative: 31.6% (120/380)
# 2019-02-05 10:58:15,082 : INFO : gram5-present-participle: 29.2% (148/506)
# 2019-02-05 10:58:15,473 : INFO : gram6-nationality-adjective: 74.6% (1023/1371)
# 2019-02-05 10:58:15,972 : INFO : gram7-past-tense: 28.2% (355/1260)
# 2019-02-05 10:58:16,300 : INFO : gram8-plural: 46.7% (434/930)
# 2019-02-05 10:58:16,429 : INFO : gram9-plural-verbs: 20.8% (71/342)
# 2019-02-05 10:58:16,433 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 10:58:16,435 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 10:58:16,437 : INFO : Total accuracy: 40.6% (3541/8724)
# 2019-02-05 10:58:16,444 : INFO : loading projection weights from ../data/models/text8_ft50dim.vec
# Semantic: 858/2325, Accuracy: 36.90%
# Syntactic: 2683/6399, Accuracy: 41.93%
#
#
# Loading text8 embeddings (dim = 50, meth = ft)
# 2019-02-05 10:58:17,159 : INFO : loaded (17839, 50) matrix from ../data/models/text8_ft50dim.vec
# 2019-02-05 10:58:17,170 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7271
# 2019-02-05 10:58:17,171 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7185
# 2019-02-05 10:58:17,171 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 10:58:17,335 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6208
# 2019-02-05 10:58:17,335 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6269
# 2019-02-05 10:58:17,336 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 10:58:17,363 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6637
# 2019-02-05 10:58:17,363 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.6733
# 2019-02-05 10:58:17,364 : INFO : Pairs with unknown words ratio: 15.0%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.72
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.63
#
# WordSim-353
# Spearman rank correlation coefficient: 0.67
#
# MEN similarity
# 2019-02-05 10:58:17,459 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.6764
# 2019-02-05 10:58:17,459 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.6722
# 2019-02-05 10:58:17,459 : INFO : Pairs with unknown words ratio: 29.8%
# 2019-02-05 10:58:17,494 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5646
# 2019-02-05 10:58:17,495 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.5659
# 2019-02-05 10:58:17,495 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 10:58:17,539 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.2844
# 2019-02-05 10:58:17,540 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.2586
# 2019-02-05 10:58:17,540 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 10:58:17,549 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 10:58:17,551 : INFO : precomputing L2-norms of word weight vectors
# Spearman rank correlation coefficient: 0.67
#
# Mturk similarity
# Spearman rank correlation coefficient: 0.57
# SimLex-999 similarity
# Spearman rank correlation coefficient: 0.26
# Accuracy:
# 2019-02-05 10:58:17,706 : INFO : capital-common-countries: 50.9% (174/342)
# 2019-02-05 10:58:17,980 : INFO : capital-world: 43.0% (303/704)
# 2019-02-05 10:58:18,032 : INFO : currency: 19.8% (21/106)
# 2019-02-05 10:58:18,366 : INFO : city-in-state: 17.2% (166/963)
# 2019-02-05 10:58:18,458 : INFO : family: 37.6% (79/210)
# 2019-02-05 10:58:18,671 : INFO : gram1-adjective-to-adverb: 44.6% (206/462)
# 2019-02-05 10:58:18,749 : INFO : gram2-opposite: 40.4% (63/156)
# 2019-02-05 10:58:19,315 : INFO : gram3-comparative: 40.1% (398/992)
# 2019-02-05 10:58:19,462 : INFO : gram4-superlative: 39.7% (151/380)
# 2019-02-05 10:58:19,669 : INFO : gram5-present-participle: 40.1% (203/506)
# 2019-02-05 10:58:20,201 : INFO : gram6-nationality-adjective: 78.6% (1078/1371)
# 2019-02-05 10:58:20,947 : INFO : gram7-past-tense: 27.2% (343/1260)
# 2019-02-05 10:58:21,551 : INFO : gram8-plural: 67.5% (628/930)
# 2019-02-05 10:58:21,690 : INFO : gram9-plural-verbs: 39.5% (135/342)
# 2019-02-05 10:58:21,693 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 10:58:21,695 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 10:58:21,698 : INFO : Total accuracy: 45.3% (3948/8724)
# 2019-02-05 10:58:21,707 : INFO : loading projection weights from ../data/models/text8_gv50dim.vec
# Semantic: 743/2325, Accuracy: 31.96%
# Syntactic: 3205/6399, Accuracy: 50.09%
#
#
# Loading text8 embeddings (dim = 50, meth = gv)
# 2019-02-05 10:58:34,770 : INFO : loaded (252830, 50) matrix from ../data/models/text8_gv50dim.vec
# WordSim-353 similarity
# 2019-02-05 10:58:35,304 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.2739
# 2019-02-05 10:58:35,304 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.3588
# 2019-02-05 10:58:35,305 : INFO : Pairs with unknown words ratio: 1.5%
# Spearman rank correlation coefficient: 0.36
#
# WordSim-353 relatedness
# 2019-02-05 10:58:35,860 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.1609
# 2019-02-05 10:58:35,861 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.1768
# 2019-02-05 10:58:35,861 : INFO : Pairs with unknown words ratio: 3.6%
# Spearman rank correlation coefficient: 0.18
#
# WordSim-353
# 2019-02-05 10:58:36,233 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.2031
# 2019-02-05 10:58:36,233 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.2532
# 2019-02-05 10:58:36,234 : INFO : Pairs with unknown words ratio: 2.5%
# Spearman rank correlation coefficient: 0.25
#
# MEN similarity
# 2019-02-05 10:58:36,848 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2098
# 2019-02-05 10:58:36,848 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2230
# 2019-02-05 10:58:36,849 : INFO : Pairs with unknown words ratio: 1.0%
# Spearman rank correlation coefficient: 0.22
#
# Mturk similarity
# 2019-02-05 10:58:37,405 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.1870
# 2019-02-05 10:58:37,406 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.2139
# 2019-02-05 10:58:37,406 : INFO : Pairs with unknown words ratio: 2.5%
# Spearman rank correlation coefficient: 0.21
# SimLex-999 similarity
# 2019-02-05 10:58:37,994 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.0828
# 2019-02-05 10:58:37,994 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.0894
# 2019-02-05 10:58:37,995 : INFO : Pairs with unknown words ratio: 6.2%
# Spearman rank correlation coefficient: 0.09
# Accuracy:
# 2019-02-05 10:58:38,556 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 10:58:38,557 : INFO : precomputing L2-norms of word weight vectors
# 2019-02-05 10:58:41,983 : INFO : capital-common-countries: 1.8% (9/506)
# 2019-02-05 10:59:11,882 : INFO : capital-world: 0.3% (14/4216)
# 2019-02-05 10:59:18,473 : INFO : currency: 0.0% (0/866)
# 2019-02-05 10:59:35,365 : INFO : city-in-state: 1.1% (27/2467)
# 2019-02-05 10:59:38,436 : INFO : family: 5.0% (21/420)
# 2019-02-05 10:59:45,012 : INFO : gram1-adjective-to-adverb: 0.1% (1/870)
# 2019-02-05 10:59:51,287 : INFO : gram2-opposite: 0.0% (0/812)
# 2019-02-05 11:00:01,512 : INFO : gram3-comparative: 1.5% (20/1332)
# 2019-02-05 11:00:09,744 : INFO : gram4-superlative: 0.3% (3/992)
# 2019-02-05 11:00:15,721 : INFO : gram5-present-participle: 0.8% (6/756)
# 2019-02-05 11:00:26,225 : INFO : gram6-nationality-adjective: 5.2% (83/1599)
# 2019-02-05 11:00:37,109 : INFO : gram7-past-tense: 1.3% (21/1560)
# 2019-02-05 11:00:46,098 : INFO : gram8-plural: 3.1% (39/1260)
# 2019-02-05 11:00:50,425 : INFO : gram9-plural-verbs: 0.8% (5/600)
# 2019-02-05 11:00:50,430 : INFO : Quadruplets with out-of-vocabulary words: 6.6%
# 2019-02-05 11:00:50,434 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:00:50,437 : INFO : Total accuracy: 1.4% (249/18256)
# 2019-02-05 11:00:50,484 : INFO : loading projection weights from ../data/models/text8_wv100dim.vec
# Semantic: 71/8475, Accuracy: 0.84%
# Syntactic: 178/9781, Accuracy: 1.82%
#
#
# Loading text8 embeddings (dim = 100, meth = wv)
# 2019-02-05 11:00:51,707 : INFO : loaded (17839, 100) matrix from ../data/models/text8_wv100dim.vec
# 2019-02-05 11:00:51,718 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7589
# 2019-02-05 11:00:51,718 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7433
# 2019-02-05 11:00:51,719 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 11:00:51,733 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6377
# 2019-02-05 11:00:51,733 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6597
# 2019-02-05 11:00:51,733 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:00:51,749 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6848
# 2019-02-05 11:00:51,749 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.7100
# 2019-02-05 11:00:51,750 : INFO : Pairs with unknown words ratio: 15.0%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.74
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.66
#
# WordSim-353
# Spearman rank correlation coefficient: 0.71
#
# MEN similarity
# 2019-02-05 11:00:51,955 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.6996
# 2019-02-05 11:00:51,955 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7023
# 2019-02-05 11:00:51,956 : INFO : Pairs with unknown words ratio: 29.8%
# 2019-02-05 11:00:51,980 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5598
# 2019-02-05 11:00:51,981 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.5692
# 2019-02-05 11:00:51,981 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:00:52,009 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.3014
# 2019-02-05 11:00:52,010 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.2887
# 2019-02-05 11:00:52,010 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 11:00:52,016 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:00:52,017 : INFO : precomputing L2-norms of word weight vectors
# 2019-02-05 11:00:52,160 : INFO : capital-common-countries: 76.3% (261/342)
# Spearman rank correlation coefficient: 0.70
#
# Mturk similarity
# Spearman rank correlation coefficient: 0.57
# SimLex-999 similarity
# Spearman rank correlation coefficient: 0.29
# Accuracy:
# 2019-02-05 11:00:52,478 : INFO : capital-world: 63.1% (444/704)
# 2019-02-05 11:00:52,531 : INFO : currency: 17.0% (18/106)
# 2019-02-05 11:00:53,061 : INFO : city-in-state: 32.1% (309/963)
# 2019-02-05 11:00:53,186 : INFO : family: 54.8% (115/210)
# 2019-02-05 11:00:53,476 : INFO : gram1-adjective-to-adverb: 25.3% (117/462)
# 2019-02-05 11:00:53,581 : INFO : gram2-opposite: 26.9% (42/156)
# 2019-02-05 11:00:54,158 : INFO : gram3-comparative: 48.0% (476/992)
# 2019-02-05 11:00:54,381 : INFO : gram4-superlative: 37.1% (141/380)
# 2019-02-05 11:00:54,689 : INFO : gram5-present-participle: 26.5% (134/506)
# 2019-02-05 11:00:55,434 : INFO : gram6-nationality-adjective: 77.1% (1057/1371)
# 2019-02-05 11:00:56,166 : INFO : gram7-past-tense: 35.2% (443/1260)
# 2019-02-05 11:00:56,759 : INFO : gram8-plural: 57.5% (535/930)
# 2019-02-05 11:00:56,969 : INFO : gram9-plural-verbs: 21.9% (75/342)
# 2019-02-05 11:00:56,973 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 11:00:56,977 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:00:56,980 : INFO : Total accuracy: 47.8% (4167/8724)
# 2019-02-05 11:00:56,989 : INFO : loading projection weights from ../data/models/text8_ft100dim.vec
# Semantic: 1147/2325, Accuracy: 49.33%
# Syntactic: 3020/6399, Accuracy: 47.19%
#
#
# Loading text8 embeddings (dim = 100, meth = ft)
# 2019-02-05 11:00:58,717 : INFO : loaded (17839, 100) matrix from ../data/models/text8_ft100dim.vec
# 2019-02-05 11:00:58,728 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7462
# 2019-02-05 11:00:58,729 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7255
# 2019-02-05 11:00:58,729 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 11:00:58,743 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6380
# 2019-02-05 11:00:58,743 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6486
# 2019-02-05 11:00:58,744 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:00:58,759 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6822
# 2019-02-05 11:00:58,760 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.6967
# 2019-02-05 11:00:58,760 : INFO : Pairs with unknown words ratio: 15.0%
# 2019-02-05 11:00:58,821 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.6910
# 2019-02-05 11:00:58,822 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.6912
# 2019-02-05 11:00:58,822 : INFO : Pairs with unknown words ratio: 29.8%
# 2019-02-05 11:00:58,847 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5887
# 2019-02-05 11:00:58,847 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.5971
# 2019-02-05 11:00:58,847 : INFO : Pairs with unknown words ratio: 12.7%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.73
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.65
#
# WordSim-353
# Spearman rank correlation coefficient: 0.70
#
# MEN similarity
# Spearman rank correlation coefficient: 0.69
#
# Mturk similarity
# Spearman rank correlation coefficient: 0.60
# SimLex-999 similarity
# 2019-02-05 11:00:59,018 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.2962
# 2019-02-05 11:00:59,018 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.2744
# 2019-02-05 11:00:59,019 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 11:00:59,026 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:00:59,027 : INFO : precomputing L2-norms of word weight vectors
# 2019-02-05 11:00:59,180 : INFO : capital-common-countries: 69.6% (238/342)
# Spearman rank correlation coefficient: 0.27
# Accuracy:
# 2019-02-05 11:00:59,566 : INFO : capital-world: 57.0% (401/704)
# 2019-02-05 11:00:59,628 : INFO : currency: 22.6% (24/106)
# 2019-02-05 11:01:00,211 : INFO : city-in-state: 28.0% (270/963)
# 2019-02-05 11:01:00,340 : INFO : family: 50.0% (105/210)
# 2019-02-05 11:01:00,646 : INFO : gram1-adjective-to-adverb: 64.5% (298/462)
# 2019-02-05 11:01:00,861 : INFO : gram2-opposite: 61.5% (96/156)
# 2019-02-05 11:01:01,615 : INFO : gram3-comparative: 60.1% (596/992)
# 2019-02-05 11:01:01,848 : INFO : gram4-superlative: 54.5% (207/380)
# 2019-02-05 11:01:02,163 : INFO : gram5-present-participle: 52.2% (264/506)
# 2019-02-05 11:01:02,951 : INFO : gram6-nationality-adjective: 90.2% (1236/1371)
# 2019-02-05 11:01:03,712 : INFO : gram7-past-tense: 39.2% (494/1260)
# 2019-02-05 11:01:04,296 : INFO : gram8-plural: 84.1% (782/930)
# 2019-02-05 11:01:04,514 : INFO : gram9-plural-verbs: 55.6% (190/342)
# 2019-02-05 11:01:04,519 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 11:01:04,522 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:01:04,526 : INFO : Total accuracy: 59.6% (5201/8724)
# 2019-02-05 11:01:04,535 : INFO : loading projection weights from ../data/models/text8_gv100dim.vec
# Semantic: 1038/2325, Accuracy: 44.65%
# Syntactic: 4163/6399, Accuracy: 65.06%
#
#
# Loading text8 embeddings (dim = 100, meth = gv)
# 2019-02-05 11:01:30,406 : INFO : loaded (252830, 100) matrix from ../data/models/text8_gv100dim.vec
# WordSim-353 similarity
# 2019-02-05 11:01:30,922 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.3215
# 2019-02-05 11:01:30,922 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.3864
# 2019-02-05 11:01:30,923 : INFO : Pairs with unknown words ratio: 1.5%
# Spearman rank correlation coefficient: 0.39
#
# WordSim-353 relatedness
# 2019-02-05 11:01:31,452 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.1904
# 2019-02-05 11:01:31,452 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.2095
# 2019-02-05 11:01:31,453 : INFO : Pairs with unknown words ratio: 3.6%
# 2019-02-05 11:01:31,981 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.2399
# 2019-02-05 11:01:31,981 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.2824
# 2019-02-05 11:01:31,982 : INFO : Pairs with unknown words ratio: 2.5%
# Spearman rank correlation coefficient: 0.21
#
# WordSim-353
# Spearman rank correlation coefficient: 0.28
#
# MEN similarity
# 2019-02-05 11:01:32,577 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2243
# 2019-02-05 11:01:32,577 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2377
# 2019-02-05 11:01:32,578 : INFO : Pairs with unknown words ratio: 1.0%
# 2019-02-05 11:01:33,113 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.2013
# 2019-02-05 11:01:33,114 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.2272
# 2019-02-05 11:01:33,114 : INFO : Pairs with unknown words ratio: 2.5%
# Spearman rank correlation coefficient: 0.24
#
# Mturk similarity
# Spearman rank correlation coefficient: 0.23
# SimLex-999 similarity
# 2019-02-05 11:01:33,664 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.0865
# 2019-02-05 11:01:33,664 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.0934
# 2019-02-05 11:01:33,665 : INFO : Pairs with unknown words ratio: 6.2%
# Spearman rank correlation coefficient: 0.09
# Accuracy:
# 2019-02-05 11:01:34,181 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:01:34,182 : INFO : precomputing L2-norms of word weight vectors
# 2019-02-05 11:01:38,968 : INFO : capital-common-countries: 3.2% (16/506)
# 2019-02-05 11:02:18,891 : INFO : capital-world: 0.6% (27/4216)
# 2019-02-05 11:02:27,422 : INFO : currency: 0.0% (0/866)
# 2019-02-05 11:02:49,951 : INFO : city-in-state: 1.3% (33/2467)
# 2019-02-05 11:02:53,999 : INFO : family: 5.2% (22/420)
# 2019-02-05 11:03:02,199 : INFO : gram1-adjective-to-adverb: 0.1% (1/870)
# 2019-02-05 11:03:10,208 : INFO : gram2-opposite: 0.1% (1/812)
# 2019-02-05 11:03:23,159 : INFO : gram3-comparative: 1.1% (14/1332)
# 2019-02-05 11:03:32,795 : INFO : gram4-superlative: 0.5% (5/992)
# 2019-02-05 11:03:40,068 : INFO : gram5-present-participle: 0.8% (6/756)
# 2019-02-05 11:03:54,172 : INFO : gram6-nationality-adjective: 6.0% (96/1599)
# 2019-02-05 11:04:08,751 : INFO : gram7-past-tense: 1.9% (30/1560)
# 2019-02-05 11:04:20,662 : INFO : gram8-plural: 4.1% (52/1260)
# 2019-02-05 11:04:26,395 : INFO : gram9-plural-verbs: 1.0% (6/600)
# 2019-02-05 11:04:26,401 : INFO : Quadruplets with out-of-vocabulary words: 6.6%
# 2019-02-05 11:04:26,404 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:04:26,407 : INFO : Total accuracy: 1.7% (309/18256)
# 2019-02-05 11:04:26,466 : INFO : loading projection weights from ../data/models/text8_wv150dim.vec
# Semantic: 98/8475, Accuracy: 1.16%
# Syntactic: 211/9781, Accuracy: 2.16%
#
#
# Loading text8 embeddings (dim = 150, meth = wv)
# 2019-02-05 11:04:28,240 : INFO : loaded (17839, 150) matrix from ../data/models/text8_wv150dim.vec
# 2019-02-05 11:04:28,252 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7545
# 2019-02-05 11:04:28,252 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7434
# 2019-02-05 11:04:28,253 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 11:04:28,267 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6446
# 2019-02-05 11:04:28,267 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6713
# 2019-02-05 11:04:28,267 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:04:28,284 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6823
# 2019-02-05 11:04:28,284 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.7174
# 2019-02-05 11:04:28,284 : INFO : Pairs with unknown words ratio: 15.0%
# 2019-02-05 11:04:28,347 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7032
# 2019-02-05 11:04:28,347 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7110
# 2019-02-05 11:04:28,348 : INFO : Pairs with unknown words ratio: 29.8%
# 2019-02-05 11:04:28,373 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5704
# 2019-02-05 11:04:28,374 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.5826
# 2019-02-05 11:04:28,374 : INFO : Pairs with unknown words ratio: 12.7%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.74
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.67
#
# WordSim-353
# Spearman rank correlation coefficient: 0.72
#
# MEN similarity
# Spearman rank correlation coefficient: 0.71
#
# Mturk similarity
# Spearman rank correlation coefficient: 0.58
# SimLex-999 similarity
# 2019-02-05 11:04:28,547 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.3038
# 2019-02-05 11:04:28,548 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.2975
# 2019-02-05 11:04:28,548 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 11:04:28,555 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:04:28,556 : INFO : precomputing L2-norms of word weight vectors
# Spearman rank correlation coefficient: 0.30
# Accuracy:
# 2019-02-05 11:04:28,820 : INFO : capital-common-countries: 79.5% (272/342)
# 2019-02-05 11:04:29,361 : INFO : capital-world: 67.8% (477/704)
# 2019-02-05 11:04:29,443 : INFO : currency: 13.2% (14/106)
# 2019-02-05 11:04:30,167 : INFO : city-in-state: 38.7% (373/963)
# 2019-02-05 11:04:30,328 : INFO : family: 63.3% (133/210)
# 2019-02-05 11:04:30,688 : INFO : gram1-adjective-to-adverb: 25.1% (116/462)
# 2019-02-05 11:04:30,821 : INFO : gram2-opposite: 24.4% (38/156)
# 2019-02-05 11:04:31,564 : INFO : gram3-comparative: 45.0% (446/992)
# 2019-02-05 11:04:31,853 : INFO : gram4-superlative: 35.5% (135/380)
# 2019-02-05 11:04:32,245 : INFO : gram5-present-participle: 27.1% (137/506)
# 2019-02-05 11:04:33,216 : INFO : gram6-nationality-adjective: 81.6% (1119/1371)
# 2019-02-05 11:04:34,169 : INFO : gram7-past-tense: 34.4% (433/1260)
# 2019-02-05 11:04:34,889 : INFO : gram8-plural: 59.7% (555/930)
# 2019-02-05 11:04:35,156 : INFO : gram9-plural-verbs: 25.4% (87/342)
# 2019-02-05 11:04:35,160 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 11:04:35,163 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:04:35,166 : INFO : Total accuracy: 49.7% (4335/8724)
# 2019-02-05 11:04:35,173 : INFO : loading projection weights from ../data/models/text8_ft150dim.vec
# Semantic: 1269/2325, Accuracy: 54.58%
# Syntactic: 3066/6399, Accuracy: 47.91%
#
#
# Loading text8 embeddings (dim = 150, meth = ft)
# 2019-02-05 11:04:36,993 : INFO : loaded (17839, 150) matrix from ../data/models/text8_ft150dim.vec
# 2019-02-05 11:04:37,005 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7471
# 2019-02-05 11:04:37,006 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7303
# 2019-02-05 11:04:37,006 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 11:04:37,167 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6266
# 2019-02-05 11:04:37,168 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6431
# 2019-02-05 11:04:37,168 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:04:37,191 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6717
# 2019-02-05 11:04:37,191 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.6936
# 2019-02-05 11:04:37,191 : INFO : Pairs with unknown words ratio: 15.0%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.73
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.64
#
# WordSim-353
# Spearman rank correlation coefficient: 0.69
#
# MEN similarity
# 2019-02-05 11:04:37,264 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7009
# 2019-02-05 11:04:37,264 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7051
# 2019-02-05 11:04:37,265 : INFO : Pairs with unknown words ratio: 29.8%
# 2019-02-05 11:04:37,290 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5943
# 2019-02-05 11:04:37,291 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.6075
# 2019-02-05 11:04:37,291 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:04:37,320 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.3036
# 2019-02-05 11:04:37,320 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.2966
# 2019-02-05 11:04:37,321 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 11:04:37,327 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:04:37,327 : INFO : precomputing L2-norms of word weight vectors
# Spearman rank correlation coefficient: 0.71
#
# Mturk similarity
# Spearman rank correlation coefficient: 0.61
# SimLex-999 similarity
# Spearman rank correlation coefficient: 0.30
# Accuracy:
# 2019-02-05 11:04:37,591 : INFO : capital-common-countries: 73.4% (251/342)
# 2019-02-05 11:04:38,142 : INFO : capital-world: 57.7% (406/704)
# 2019-02-05 11:04:38,225 : INFO : currency: 17.0% (18/106)
# 2019-02-05 11:04:38,965 : INFO : city-in-state: 29.7% (286/963)
# 2019-02-05 11:04:39,131 : INFO : family: 55.2% (116/210)
# 2019-02-05 11:04:39,502 : INFO : gram1-adjective-to-adverb: 70.3% (325/462)
# 2019-02-05 11:04:39,633 : INFO : gram2-opposite: 66.7% (104/156)
# 2019-02-05 11:04:40,405 : INFO : gram3-comparative: 66.6% (661/992)
# 2019-02-05 11:04:40,697 : INFO : gram4-superlative: 60.5% (230/380)
# 2019-02-05 11:04:41,101 : INFO : gram5-present-participle: 55.1% (279/506)
# 2019-02-05 11:04:42,120 : INFO : gram6-nationality-adjective: 94.2% (1292/1371)
# 2019-02-05 11:04:43,101 : INFO : gram7-past-tense: 40.4% (509/1260)
# 2019-02-05 11:04:43,831 : INFO : gram8-plural: 89.6% (833/930)
# 2019-02-05 11:04:44,099 : INFO : gram9-plural-verbs: 69.0% (236/342)
# 2019-02-05 11:04:44,103 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 11:04:44,106 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:04:44,109 : INFO : Total accuracy: 63.6% (5546/8724)
# 2019-02-05 11:04:44,117 : INFO : loading projection weights from ../data/models/text8_gv150dim.vec
# Semantic: 1077/2325, Accuracy: 46.32%
# Syntactic: 4469/6399, Accuracy: 69.84%
#
#
# Loading text8 embeddings (dim = 150, meth = gv)
# 2019-02-05 11:05:20,748 : INFO : loaded (252830, 150) matrix from ../data/models/text8_gv150dim.vec
# WordSim-353 similarity
# 2019-02-05 11:05:21,265 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.3342
# 2019-02-05 11:05:21,265 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.3882
# 2019-02-05 11:05:21,266 : INFO : Pairs with unknown words ratio: 1.5%
# Spearman rank correlation coefficient: 0.39
#
# WordSim-353 relatedness
# 2019-02-05 11:05:21,794 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.2028
# 2019-02-05 11:05:21,795 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.2266
# 2019-02-05 11:05:21,795 : INFO : Pairs with unknown words ratio: 3.6%
# 2019-02-05 11:05:22,143 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.2521
# 2019-02-05 11:05:22,144 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.2936
# 2019-02-05 11:05:22,144 : INFO : Pairs with unknown words ratio: 2.5%
# Spearman rank correlation coefficient: 0.23
#
# WordSim-353
# Spearman rank correlation coefficient: 0.29
#
# MEN similarity
# 2019-02-05 11:05:22,736 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2246
# 2019-02-05 11:05:22,737 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2384
# 2019-02-05 11:05:22,737 : INFO : Pairs with unknown words ratio: 1.0%
# Spearman rank correlation coefficient: 0.24
#
# Mturk similarity
# 2019-02-05 11:05:23,267 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.2040
# 2019-02-05 11:05:23,268 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.2275
# 2019-02-05 11:05:23,268 : INFO : Pairs with unknown words ratio: 2.5%
# 2019-02-05 11:05:23,799 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.0906
# 2019-02-05 11:05:23,800 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.0990
# 2019-02-05 11:05:23,800 : INFO : Pairs with unknown words ratio: 6.2%
# Spearman rank correlation coefficient: 0.23
# SimLex-999 similarity
# Spearman rank correlation coefficient: 0.10
# Accuracy:
# 2019-02-05 11:05:24,305 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:05:24,306 : INFO : precomputing L2-norms of word weight vectors
# 2019-02-05 11:05:32,656 : INFO : capital-common-countries: 4.2% (21/506)
# 2019-02-05 11:06:41,386 : INFO : capital-world: 0.6% (25/4216)
# 2019-02-05 11:06:55,808 : INFO : currency: 0.0% (0/866)
# 2019-02-05 11:07:37,053 : INFO : city-in-state: 0.7% (17/2467)
# 2019-02-05 11:07:44,042 : INFO : family: 6.4% (27/420)
# 2019-02-05 11:07:58,281 : INFO : gram1-adjective-to-adverb: 0.1% (1/870)
# 2019-02-05 11:08:11,961 : INFO : gram2-opposite: 0.0% (0/812)
# 2019-02-05 11:08:34,874 : INFO : gram3-comparative: 1.1% (15/1332)
# 2019-02-05 11:08:51,860 : INFO : gram4-superlative: 0.6% (6/992)
# 2019-02-05 11:09:05,022 : INFO : gram5-present-participle: 1.3% (10/756)
# 2019-02-05 11:09:31,915 : INFO : gram6-nationality-adjective: 5.8% (92/1599)
# 2019-02-05 11:09:58,839 : INFO : gram7-past-tense: 2.2% (35/1560)
# 2019-02-05 11:10:21,033 : INFO : gram8-plural: 4.2% (53/1260)
# 2019-02-05 11:10:31,657 : INFO : gram9-plural-verbs: 1.2% (7/600)
# 2019-02-05 11:10:31,665 : INFO : Quadruplets with out-of-vocabulary words: 6.6%
# 2019-02-05 11:10:31,669 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:10:31,672 : INFO : Total accuracy: 1.7% (309/18256)
# 2019-02-05 11:10:31,747 : INFO : loading projection weights from ../data/models/text8_wv200dim.vec
# Semantic: 90/8475, Accuracy: 1.06%
# Syntactic: 219/9781, Accuracy: 2.24%
#
#
# Loading text8 embeddings (dim = 200, meth = wv)
# 2019-02-05 11:10:34,618 : INFO : loaded (17839, 200) matrix from ../data/models/text8_wv200dim.vec
# 2019-02-05 11:10:34,637 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7560
# 2019-02-05 11:10:34,638 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7542
# 2019-02-05 11:10:34,638 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 11:10:34,664 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6463
# 2019-02-05 11:10:34,664 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6707
# 2019-02-05 11:10:34,665 : INFO : Pairs with unknown words ratio: 12.7%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.75
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.67
#
# WordSim-353
# 2019-02-05 11:10:34,845 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6799
# 2019-02-05 11:10:34,846 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.7190
# 2019-02-05 11:10:34,846 : INFO : Pairs with unknown words ratio: 15.0%
# 2019-02-05 11:10:34,924 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7022
# 2019-02-05 11:10:34,924 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7124
# 2019-02-05 11:10:34,925 : INFO : Pairs with unknown words ratio: 29.8%
# 2019-02-05 11:10:34,953 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5639
# 2019-02-05 11:10:34,954 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.5837
# 2019-02-05 11:10:34,954 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:10:34,992 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.2998
# 2019-02-05 11:10:34,992 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.3021
# 2019-02-05 11:10:34,993 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 11:10:34,999 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:10:35,000 : INFO : precomputing L2-norms of word weight vectors
# Spearman rank correlation coefficient: 0.72
#
# MEN similarity
# Spearman rank correlation coefficient: 0.71
#
# Mturk similarity
# Spearman rank correlation coefficient: 0.58
# SimLex-999 similarity
# Spearman rank correlation coefficient: 0.30
# Accuracy:
# 2019-02-05 11:10:35,288 : INFO : capital-common-countries: 78.1% (267/342)
# 2019-02-05 11:10:35,890 : INFO : capital-world: 64.9% (457/704)
# 2019-02-05 11:10:35,981 : INFO : currency: 10.4% (11/106)
# 2019-02-05 11:10:36,795 : INFO : city-in-state: 42.7% (411/963)
# 2019-02-05 11:10:36,975 : INFO : family: 69.0% (145/210)
# 2019-02-05 11:10:37,381 : INFO : gram1-adjective-to-adverb: 21.9% (101/462)
# 2019-02-05 11:10:37,528 : INFO : gram2-opposite: 27.6% (43/156)
# 2019-02-05 11:10:38,585 : INFO : gram3-comparative: 44.9% (445/992)
# 2019-02-05 11:10:39,008 : INFO : gram4-superlative: 31.6% (120/380)
# 2019-02-05 11:10:39,659 : INFO : gram5-present-participle: 22.5% (114/506)
# 2019-02-05 11:10:41,236 : INFO : gram6-nationality-adjective: 84.3% (1156/1371)
# 2019-02-05 11:10:43,023 : INFO : gram7-past-tense: 36.0% (454/1260)
# 2019-02-05 11:10:44,183 : INFO : gram8-plural: 55.7% (518/930)
# 2019-02-05 11:10:44,627 : INFO : gram9-plural-verbs: 32.7% (112/342)
# 2019-02-05 11:10:44,631 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 11:10:44,636 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:10:44,639 : INFO : Total accuracy: 49.9% (4354/8724)
# 2019-02-05 11:10:44,647 : INFO : loading projection weights from ../data/models/text8_ft200dim.vec
# Semantic: 1291/2325, Accuracy: 55.53%
# Syntactic: 3063/6399, Accuracy: 47.87%
#
#
# Loading text8 embeddings (dim = 200, meth = ft)
# 2019-02-05 11:10:47,463 : INFO : loaded (17839, 200) matrix from ../data/models/text8_ft200dim.vec
# 2019-02-05 11:10:47,483 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7473
# 2019-02-05 11:10:47,484 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7347
# 2019-02-05 11:10:47,485 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 11:10:47,506 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6335
# 2019-02-05 11:10:47,507 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6586
# 2019-02-05 11:10:47,507 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:10:47,535 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6763
# 2019-02-05 11:10:47,536 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.7120
# 2019-02-05 11:10:47,536 : INFO : Pairs with unknown words ratio: 15.0%
# 2019-02-05 11:10:47,634 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7016
# 2019-02-05 11:10:47,635 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7090
# 2019-02-05 11:10:47,635 : INFO : Pairs with unknown words ratio: 29.8%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.73
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.66
#
# WordSim-353
# Spearman rank correlation coefficient: 0.71
#
# MEN similarity
# Spearman rank correlation coefficient: 0.71
#
# Mturk similarity
# 2019-02-05 11:10:47,851 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5906
# 2019-02-05 11:10:47,852 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.6065
# 2019-02-05 11:10:47,852 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:10:47,898 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.3101
# 2019-02-05 11:10:47,899 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.3119
# 2019-02-05 11:10:47,899 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 11:10:47,909 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:10:47,910 : INFO : precomputing L2-norms of word weight vectors
# Spearman rank correlation coefficient: 0.61
# SimLex-999 similarity
# Spearman rank correlation coefficient: 0.31
# Accuracy:
# 2019-02-05 11:10:48,437 : INFO : capital-common-countries: 71.3% (244/342)
# 2019-02-05 11:10:49,050 : INFO : capital-world: 59.7% (420/704)
# 2019-02-05 11:10:49,149 : INFO : currency: 9.4% (10/106)
# 2019-02-05 11:10:50,022 : INFO : city-in-state: 32.7% (315/963)
# 2019-02-05 11:10:50,215 : INFO : family: 56.2% (118/210)
# 2019-02-05 11:10:50,650 : INFO : gram1-adjective-to-adverb: 72.3% (334/462)
# 2019-02-05 11:10:50,807 : INFO : gram2-opposite: 67.9% (106/156)
# 2019-02-05 11:10:51,710 : INFO : gram3-comparative: 69.2% (686/992)
# 2019-02-05 11:10:52,049 : INFO : gram4-superlative: 58.2% (221/380)
# 2019-02-05 11:10:52,516 : INFO : gram5-present-participle: 51.2% (259/506)
# 2019-02-05 11:10:53,660 : INFO : gram6-nationality-adjective: 96.9% (1328/1371)
# 2019-02-05 11:10:54,817 : INFO : gram7-past-tense: 38.1% (480/1260)
# 2019-02-05 11:10:55,669 : INFO : gram8-plural: 91.7% (853/930)
# 2019-02-05 11:10:55,990 : INFO : gram9-plural-verbs: 77.5% (265/342)
# 2019-02-05 11:10:55,994 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 11:10:55,997 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:10:56,000 : INFO : Total accuracy: 64.6% (5639/8724)
# 2019-02-05 11:10:56,008 : INFO : loading projection weights from ../data/models/text8_gv200dim.vec
# Semantic: 1107/2325, Accuracy: 47.61%
# Syntactic: 4532/6399, Accuracy: 70.82%
#
#
# Loading text8 embeddings (dim = 200, meth = gv)
# 2019-02-05 11:11:53,558 : INFO : loaded (252830, 200) matrix from ../data/models/text8_gv200dim.vec
# WordSim-353 similarity
# 2019-02-05 11:11:54,133 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.3420
# 2019-02-05 11:11:54,134 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.3909
# 2019-02-05 11:11:54,134 : INFO : Pairs with unknown words ratio: 1.5%
# Spearman rank correlation coefficient: 0.39
#
# WordSim-353 relatedness
# 2019-02-05 11:11:54,831 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.2101
# 2019-02-05 11:11:54,832 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.2286
# 2019-02-05 11:11:54,833 : INFO : Pairs with unknown words ratio: 3.6%
# Spearman rank correlation coefficient: 0.23
#
# WordSim-353
# 2019-02-05 11:11:55,517 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.2599
# 2019-02-05 11:11:55,518 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.2969
# 2019-02-05 11:11:55,518 : INFO : Pairs with unknown words ratio: 2.5%
# Spearman rank correlation coefficient: 0.30
#
# MEN similarity
# 2019-02-05 11:11:56,182 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2297
# 2019-02-05 11:11:56,182 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2437
# 2019-02-05 11:11:56,183 : INFO : Pairs with unknown words ratio: 1.0%
# Spearman rank correlation coefficient: 0.24
#
# Mturk similarity
# 2019-02-05 11:11:56,765 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.2068
# 2019-02-05 11:11:56,766 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.2271
# 2019-02-05 11:11:56,766 : INFO : Pairs with unknown words ratio: 2.5%
# Spearman rank correlation coefficient: 0.23
# SimLex-999 similarity
# 2019-02-05 11:11:57,509 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.0923
# 2019-02-05 11:11:57,509 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.0999
# 2019-02-05 11:11:57,510 : INFO : Pairs with unknown words ratio: 6.2%
# Spearman rank correlation coefficient: 0.10
# Accuracy:
# 2019-02-05 11:11:58,340 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:11:58,341 : INFO : precomputing L2-norms of word weight vectors
# 2019-02-05 11:12:08,583 : INFO : capital-common-countries: 3.6% (18/506)
# 2019-02-05 11:13:28,898 : INFO : capital-world: 0.6% (24/4216)
# 2019-02-05 11:13:45,961 : INFO : currency: 0.0% (0/866)
# 2019-02-05 11:14:32,769 : INFO : city-in-state: 0.6% (15/2467)
# 2019-02-05 11:14:41,113 : INFO : family: 6.2% (26/420)
# 2019-02-05 11:14:57,697 : INFO : gram1-adjective-to-adverb: 0.1% (1/870)
# 2019-02-05 11:15:12,746 : INFO : gram2-opposite: 0.0% (0/812)
# 2019-02-05 11:15:37,845 : INFO : gram3-comparative: 1.3% (17/1332)
# 2019-02-05 11:15:55,941 : INFO : gram4-superlative: 0.6% (6/992)
# 2019-02-05 11:16:09,730 : INFO : gram5-present-participle: 0.7% (5/756)
# 2019-02-05 11:16:40,409 : INFO : gram6-nationality-adjective: 6.1% (98/1599)
# 2019-02-05 11:17:09,025 : INFO : gram7-past-tense: 2.2% (34/1560)
# 2019-02-05 11:17:33,138 : INFO : gram8-plural: 4.4% (55/1260)
# 2019-02-05 11:17:44,566 : INFO : gram9-plural-verbs: 1.2% (7/600)
# 2019-02-05 11:17:44,573 : INFO : Quadruplets with out-of-vocabulary words: 6.6%
# 2019-02-05 11:17:44,577 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:17:44,580 : INFO : Total accuracy: 1.7% (306/18256)
# 2019-02-05 11:17:44,656 : INFO : loading projection weights from ../data/models/text8_wv250dim.vec
# Semantic: 83/8475, Accuracy: 0.98%
# Syntactic: 223/9781, Accuracy: 2.28%
#
#
# Loading text8 embeddings (dim = 250, meth = wv)
# 2019-02-05 11:17:47,528 : INFO : loaded (17839, 250) matrix from ../data/models/text8_wv250dim.vec
# 2019-02-05 11:17:47,540 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7409
# 2019-02-05 11:17:47,541 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7407
# 2019-02-05 11:17:47,542 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 11:17:47,560 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6388
# 2019-02-05 11:17:47,561 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6656
# 2019-02-05 11:17:47,561 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:17:47,586 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6673
# 2019-02-05 11:17:47,586 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.7113
# 2019-02-05 11:17:47,587 : INFO : Pairs with unknown words ratio: 15.0%
# 2019-02-05 11:17:47,700 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.6964
# 2019-02-05 11:17:47,700 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7093
# 2019-02-05 11:17:47,701 : INFO : Pairs with unknown words ratio: 29.8%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.74
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.67
#
# WordSim-353
# Spearman rank correlation coefficient: 0.71
#
# MEN similarity
# Spearman rank correlation coefficient: 0.71
#
# Mturk similarity
# 2019-02-05 11:17:47,747 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5672
# 2019-02-05 11:17:47,748 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.5883
# 2019-02-05 11:17:47,748 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:17:47,804 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.2992
# 2019-02-05 11:17:47,805 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.3073
# 2019-02-05 11:17:47,806 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 11:17:47,817 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:17:47,818 : INFO : precomputing L2-norms of word weight vectors
# Spearman rank correlation coefficient: 0.59
# SimLex-999 similarity
# Spearman rank correlation coefficient: 0.31
# Accuracy:
# 2019-02-05 11:17:48,526 : INFO : capital-common-countries: 79.2% (271/342)
# 2019-02-05 11:17:49,630 : INFO : capital-world: 64.2% (452/704)
# 2019-02-05 11:17:49,756 : INFO : currency: 12.3% (13/106)
# 2019-02-05 11:17:50,876 : INFO : city-in-state: 45.6% (439/963)
# 2019-02-05 11:17:51,119 : INFO : family: 61.4% (129/210)
# 2019-02-05 11:17:51,881 : INFO : gram1-adjective-to-adverb: 24.0% (111/462)
# 2019-02-05 11:17:52,078 : INFO : gram2-opposite: 28.8% (45/156)
# 2019-02-05 11:17:53,555 : INFO : gram3-comparative: 45.6% (452/992)
# 2019-02-05 11:17:54,095 : INFO : gram4-superlative: 30.3% (115/380)
# 2019-02-05 11:17:54,698 : INFO : gram5-present-participle: 23.5% (119/506)
# 2019-02-05 11:17:56,417 : INFO : gram6-nationality-adjective: 85.0% (1166/1371)
# 2019-02-05 11:17:58,536 : INFO : gram7-past-tense: 33.1% (417/1260)
# 2019-02-05 11:17:59,731 : INFO : gram8-plural: 55.5% (516/930)
# 2019-02-05 11:18:00,173 : INFO : gram9-plural-verbs: 30.1% (103/342)
# 2019-02-05 11:18:00,177 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 11:18:00,180 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:18:00,183 : INFO : Total accuracy: 49.8% (4348/8724)
# 2019-02-05 11:18:00,192 : INFO : loading projection weights from ../data/models/text8_ft250dim.vec
# Semantic: 1304/2325, Accuracy: 56.09%
# Syntactic: 3044/6399, Accuracy: 47.57%
#
#
# Loading text8 embeddings (dim = 250, meth = ft)
# 2019-02-05 11:18:03,212 : INFO : loaded (17839, 250) matrix from ../data/models/text8_ft250dim.vec
# 2019-02-05 11:18:03,223 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7514
# 2019-02-05 11:18:03,224 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.7448
# 2019-02-05 11:18:03,224 : INFO : Pairs with unknown words ratio: 16.3%
# 2019-02-05 11:18:03,243 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6482
# 2019-02-05 11:18:03,243 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.6647
# 2019-02-05 11:18:03,244 : INFO : Pairs with unknown words ratio: 12.7%
# WordSim-353 similarity
# Spearman rank correlation coefficient: 0.74
#
# WordSim-353 relatedness
# Spearman rank correlation coefficient: 0.66
#
# WordSim-353
# 2019-02-05 11:18:03,419 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.6806
# 2019-02-05 11:18:03,420 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.7155
# 2019-02-05 11:18:03,420 : INFO : Pairs with unknown words ratio: 15.0%
# 2019-02-05 11:18:03,528 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7001
# 2019-02-05 11:18:03,528 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.7106
# 2019-02-05 11:18:03,529 : INFO : Pairs with unknown words ratio: 29.8%
# 2019-02-05 11:18:03,570 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.5880
# 2019-02-05 11:18:03,571 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.6055
# 2019-02-05 11:18:03,572 : INFO : Pairs with unknown words ratio: 12.7%
# 2019-02-05 11:18:03,624 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.3105
# 2019-02-05 11:18:03,625 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.3284
# 2019-02-05 11:18:03,625 : INFO : Pairs with unknown words ratio: 18.7%
# 2019-02-05 11:18:03,635 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# Spearman rank correlation coefficient: 0.72
#
# MEN similarity
# Spearman rank correlation coefficient: 0.71
#
# Mturk similarity
# Spearman rank correlation coefficient: 0.61
# SimLex-999 similarity
# Spearman rank correlation coefficient: 0.33
# Accuracy:
# 2019-02-05 11:18:03,636 : INFO : precomputing L2-norms of word weight vectors
# 2019-02-05 11:18:04,209 : INFO : capital-common-countries: 69.0% (236/342)
# 2019-02-05 11:18:05,238 : INFO : capital-world: 56.8% (400/704)
# 2019-02-05 11:18:05,478 : INFO : currency: 3.8% (4/106)
# 2019-02-05 11:18:06,615 : INFO : city-in-state: 31.0% (299/963)
# 2019-02-05 11:18:06,861 : INFO : family: 54.3% (114/210)
# 2019-02-05 11:18:07,404 : INFO : gram1-adjective-to-adverb: 76.0% (351/462)
# 2019-02-05 11:18:07,595 : INFO : gram2-opposite: 71.8% (112/156)
# 2019-02-05 11:18:08,752 : INFO : gram3-comparative: 74.3% (737/992)
# 2019-02-05 11:18:09,184 : INFO : gram4-superlative: 61.3% (233/380)
# 2019-02-05 11:18:09,767 : INFO : gram5-present-participle: 51.0% (258/506)
# 2019-02-05 11:18:11,284 : INFO : gram6-nationality-adjective: 97.0% (1330/1371)
# 2019-02-05 11:18:12,783 : INFO : gram7-past-tense: 39.4% (496/1260)
# 2019-02-05 11:18:13,849 : INFO : gram8-plural: 91.2% (848/930)
# 2019-02-05 11:18:14,251 : INFO : gram9-plural-verbs: 78.1% (267/342)
# 2019-02-05 11:18:14,256 : INFO : Quadruplets with out-of-vocabulary words: 55.4%
# 2019-02-05 11:18:14,259 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:18:14,263 : INFO : Total accuracy: 65.2% (5685/8724)
# 2019-02-05 11:18:14,271 : INFO : loading projection weights from ../data/models/text8_gv250dim.vec
# Semantic: 1053/2325, Accuracy: 45.29%
# Syntactic: 4632/6399, Accuracy: 72.39%
#
#
# Loading text8 embeddings (dim = 250, meth = gv)
# 2019-02-05 11:19:20,125 : INFO : loaded (252830, 250) matrix from ../data/models/text8_gv250dim.vec
# WordSim-353 similarity
# 2019-02-05 11:19:20,764 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.3491
# 2019-02-05 11:19:20,765 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_similarity_goldstandard.txt: 0.3925
# 2019-02-05 11:19:20,765 : INFO : Pairs with unknown words ratio: 1.5%
# Spearman rank correlation coefficient: 0.39
#
# WordSim-353 relatedness
# 2019-02-05 11:19:21,228 : INFO : Pearson correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.2208
# 2019-02-05 11:19:21,228 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim_relatedness_goldstandard.txt: 0.2413
# 2019-02-05 11:19:21,229 : INFO : Pairs with unknown words ratio: 3.6%
# Spearman rank correlation coefficient: 0.24
#
# WordSim-353
# 2019-02-05 11:19:21,834 : INFO : Pearson correlation coefficient against ../eval_files/wordsim353.tsv: 0.2679
# 2019-02-05 11:19:21,834 : INFO : Spearman rank-order correlation coefficient against ../eval_files/wordsim353.tsv: 0.3028
# 2019-02-05 11:19:21,835 : INFO : Pairs with unknown words ratio: 2.5%
# Spearman rank correlation coefficient: 0.30
#
# MEN similarity
# 2019-02-05 11:19:22,451 : INFO : Pearson correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2292
# 2019-02-05 11:19:22,452 : INFO : Spearman rank-order correlation coefficient against ../eval_files/MEN_dataset_natural_form_full.tsv: 0.2427
# 2019-02-05 11:19:22,452 : INFO : Pairs with unknown words ratio: 1.0%
# Spearman rank correlation coefficient: 0.24
#
# Mturk similarity
# 2019-02-05 11:19:23,222 : INFO : Pearson correlation coefficient against ../eval_files/mturk-771.tsv: 0.2079
# 2019-02-05 11:19:23,223 : INFO : Spearman rank-order correlation coefficient against ../eval_files/mturk-771.tsv: 0.2296
# 2019-02-05 11:19:23,223 : INFO : Pairs with unknown words ratio: 2.5%
# Spearman rank correlation coefficient: 0.23
# SimLex-999 similarity
# 2019-02-05 11:19:23,599 : INFO : Pearson correlation coefficient against ../eval_files/simlex999.txt: 0.0921
# 2019-02-05 11:19:23,600 : INFO : Spearman rank-order correlation coefficient against ../eval_files/simlex999.txt: 0.1011
# 2019-02-05 11:19:23,600 : INFO : Pairs with unknown words ratio: 6.2%
# 2019-02-05 11:19:24,115 : INFO : Evaluating word analogies for top 300000 words in the model on ../eval_files/questions-words.txt
# 2019-02-05 11:19:24,116 : INFO : precomputing L2-norms of word weight vectors
# Spearman rank correlation coefficient: 0.10
# Accuracy:
# 2019-02-05 11:19:37,214 : INFO : capital-common-countries: 4.2% (21/506)
# 2019-02-05 11:21:21,813 : INFO : capital-world: 0.5% (20/4216)
# 2019-02-05 11:21:42,910 : INFO : currency: 0.1% (1/866)
# 2019-02-05 11:22:44,494 : INFO : city-in-state: 0.7% (18/2467)
# 2019-02-05 11:22:55,152 : INFO : family: 6.9% (29/420)
# 2019-02-05 11:23:17,044 : INFO : gram1-adjective-to-adverb: 0.1% (1/870)
# 2019-02-05 11:23:37,367 : INFO : gram2-opposite: 0.0% (0/812)
# 2019-02-05 11:24:09,941 : INFO : gram3-comparative: 1.4% (18/1332)
# 2019-02-05 11:24:35,312 : INFO : gram4-superlative: 0.6% (6/992)
# 2019-02-05 11:24:53,747 : INFO : gram5-present-participle: 1.2% (9/756)
# 2019-02-05 11:25:33,862 : INFO : gram6-nationality-adjective: 6.4% (102/1599)
# 2019-02-05 11:26:12,720 : INFO : gram7-past-tense: 2.2% (35/1560)
# 2019-02-05 11:26:44,530 : INFO : gram8-plural: 4.4% (55/1260)
# 2019-02-05 11:26:59,287 : INFO : gram9-plural-verbs: 0.8% (5/600)
# 2019-02-05 11:26:59,293 : INFO : Quadruplets with out-of-vocabulary words: 6.6%
# 2019-02-05 11:26:59,297 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-02-05 11:26:59,301 : INFO : Total accuracy: 1.8% (320/18256)
# Semantic: 89/8475, Accuracy: 1.05%
# Syntactic: 231/9781, Accuracy: 2.36%
#
# {'text8': [[0.7348445533431484, 0.6439758818472558, 0.6954521051026731, 0.6829373516103544, 0.5615490684159623, 0.26327690310060836, 36.903225806451616, 41.92842631661197], [0.7184613420236518, 0.6268979899497417, 0.6733009813530549, 0.6721648189389509, 0.5658788850272016, 0.25862204133704736, 31.956989247311828, 50.085950929832784], [0.3588060028416238, 0.17683502330300224, 0.2531674592188968, 0.2229703794846261, 0.21389164696347052, 0.08941852792850877, 0.8377581120943953, 1.8198548205704939], [0.7432950855572231, 0.659688939910685, 0.7100447748360987, 0.7023493950885519, 0.5691726966564085, 0.2886527579027332, 49.333333333333336, 47.19487419909361], [0.7255476244208279, 0.6486384066793034, 0.6967068102471933, 0.6912408440881559, 0.5970936135667261, 0.27441049405759166, 44.645161290322584, 65.0570401625254], [0.3863536729366053, 0.2095371571957508, 0.2823944212018308, 0.2376873067955755, 0.2272098453239693, 0.09339211825668843, 1.1563421828908556, 2.15724363562008],!
#   [0.7434233274827149, 0.6713165127151893, 0.7173903334345706, 0.7110052782315971, 0.5825507074102004, 0.2974639219523706, 54.58064516129032, 47.91373652133146], [0.7303206667524659, 0.6431227198221506, 0.6936080485512687, 0.7051300160782834, 0.60747466614803, 0.29664834696574577, 46.32258064516129, 69.83903734958588], [0.3882220362073142, 0.2266022490979691, 0.2936379754613936, 0.23843700750498373, 0.22752125019402347, 0.09895654946112663, 1.0619469026548674, 2.2390348635108883], [0.7541809930039709, 0.6706927013797922, 0.7189974938322274, 0.7123673743728317, 0.5836624955504033, 0.30210932491543263, 55.526881720430104, 47.86685419596812], [0.7346650146474599, 0.6585929028308769, 0.7119850565606483, 0.7089559442033413, 0.6064721238592157, 0.3119384419367782, 47.61290322580645, 70.82356618221597], [0.3908501955411417, 0.22862117295554732, 0.2968770140798424, 0.24370388219619146, 0.2270974652872704, 0.09985067037450046, 0.9793510324483776, 2.279930477456293], [0.74071803353067!
#  33, 0.6656312077803902, 0.7112565897764226, 0.7092533636106866!
#  , 0.5883009169288623, 0.30734872710129835, 56.086021505376344, 47.56993280200031], [0.7447643716178579, 0.664732964538635, 0.7154669411168549, 0.710559453158029, 0.6054722192179842, 0.3284144396239234, 45.29032258064516, 72.3863103609939], [0.39246954371515236, 0.24130593606569187, 0.3028422988091821, 0.24273520812171617, 0.22955345938496993, 0.10109784469298705, 1.0501474926253687, 2.3617217053471014]]}

# %%
len(eval_all['text8'])
# Out:
# 15

# %%
import pandas as pd

def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

def highlight_max(data, color='yellow'):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr = 'background-color: {}'.format(color)
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]
    else:  # from .apply(axis=None)
        is_max = data == data.max().max()
        return pd.DataFrame(np.where(is_max, attr, ''),
                            index=data.index, columns=data.columns)

# %%
(eval_all[cp_name][2][7])

# %%
def eval_table_oneDim(eval_all):
    data_eval = [["WordSim_sim", eval_all[0][0], eval_all[1][0], eval_all[2][0]
                 ],

                 ["WordSim_rel", eval_all[0][1], eval_all[1][1], eval_all[2][1]
                 ],

                 ["WordSim_353", eval_all[0][2], eval_all[1][2], eval_all[2][2]
                 ],

                 ["MEN", eval_all[0][3], eval_all[1][3], eval_all[2][3]
                 ],

                 ["M.Turk", eval_all[0][4], eval_all[1][4], eval_all[2][4]
                 ],

                 ["SimLex", eval_all[0][5], eval_all[1][5], eval_all[2][5]
                 ],

                 ["Analogy_sem", eval_all[0][6], eval_all[1][6], eval_all[2][6]
                 ],
                 ["Analogy_syn", eval_all[0][7], eval_all[1][7], eval_all[2][7]
                 ]
                ]


    return data_eval

colnames = ["evals", "wv_50", 
                         "ft_50", 
                         "gv_50"
               ]

# cp_name = 'brown'
cp_name = 'text8'
res_eval = eval_table_oneDim(eval_all[cp_name])
df = pd.DataFrame(res_eval, columns = colnames)

(df.style
   .applymap(color_negative_red, subset = pd.IndexSlice[:, colnames[1:len(colnames)]])
   .apply(highlight_max, axis= 1, subset = pd.IndexSlice[0:6, colnames[1:len(colnames)]])
   .format({
        'wv_50': '{:,.3f}'.format,
        'ft_50': '{:,.3f}'.format,
        'gv_50': '{:,.3f}'.format,
})
)
# Out:
# <style  type="text/css" >
#     #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row0_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row0_col2 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row0_col3 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row1_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row1_col2 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row1_col3 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row2_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row2_col2 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row2_col3 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row3_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row3_col2 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row3_col3 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row4_col1 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row4_col2 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row4_col3 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row5_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row5_col2 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row5_col3 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row6_col1 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row6_col2 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row6_col3 {
#             color:  black;
#             : ;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row7_col1 {
#             color:  black;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row7_col2 {
#             color:  black;
#         }    #T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row7_col3 {
#             color:  black;
#         }</style>
# <table id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >evals</th>
#         <th class="col_heading level0 col1" >wv_50</th>
#         <th class="col_heading level0 col2" >ft_50</th>
#         <th class="col_heading level0 col3" >gv_50</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row0_col0" class="data row0 col0" >WordSim_sim</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row0_col1" class="data row0 col1" >0.735</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row0_col2" class="data row0 col2" >0.718</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row0_col3" class="data row0 col3" >0.359</td>
#     </tr>    <tr>
#         <th id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row1_col0" class="data row1 col0" >WordSim_rel</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row1_col1" class="data row1 col1" >0.644</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row1_col2" class="data row1 col2" >0.627</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row1_col3" class="data row1 col3" >0.177</td>
#     </tr>    <tr>
#         <th id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row2_col0" class="data row2 col0" >WordSim_353</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row2_col1" class="data row2 col1" >0.695</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row2_col2" class="data row2 col2" >0.673</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row2_col3" class="data row2 col3" >0.253</td>
#     </tr>    <tr>
#         <th id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row3_col0" class="data row3 col0" >MEN</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row3_col1" class="data row3 col1" >0.683</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row3_col2" class="data row3 col2" >0.672</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row3_col3" class="data row3 col3" >0.223</td>
#     </tr>    <tr>
#         <th id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889row4_col0" class="data row4 col0" >M.Turk</td>
#         <td id="T_ef63a46c_28d3_11e9_a8f9_9cb6d08c5889
                   eval_all[0][6], eval_all[1][6], eval_all[2][6], eval_all[3][6], eval_all[4][6],
                   eval_all[5][6], eval_all[6][6], eval_all[7][6], eval_all[8][6], eval_all[9][6],
                   eval_all[10][6], eval_all[11][6], eval_all[12][6], eval_all[13][6], eval_all[14][6]
                  
                 ],
                 ["Google_syn", 
                  
                   eval_all[0][7], eval_all[1][7], eval_all[2][7], eval_all[3][7], eval_all[4][7],
                   eval_all[5][7], eval_all[6][7], eval_all[7][7], eval_all[8][7], eval_all[9][7],
                   eval_all[10][7], eval_all[11][7], eval_all[12][7], eval_all[13][7], eval_all[14][7]
                  
                 ]
                ]


    return data_eval

colnames = ["evals", "wv_50", "wv_100", "wv_150", "wv_200", "wv_250",
                     "ft_50", "ft_100", "ft_150", "ft_200", "ft_250",
                     "gv_50", "gv_100", "gv_150", "gv_200", "gv_250"
               ]

# cp_name = 'brown'
cp_name = 'text8'
res_eval = eval_table(eval_all[cp_name])
df = pd.DataFrame(res_eval, columns = colnames)

(df.style
   .applymap(color_negative_red, subset = pd.IndexSlice[:, colnames[1:len(colnames)]])
   .apply(highlight_max, axis= 1, subset = pd.IndexSlice[0:6, colnames[1:len(colnames)]])
   .format({
        'wv_50': '{:,.3f}'.format,
        'wv_100': '{:,.3f}'.format,
        'wv_150': '{:,.3f}'.format,
        'wv_200': '{:,.3f}'.format,
        'wv_250': '{:,.3f}'.format,
        'ft_50': '{:,.3f}'.format,
        'ft_100': '{:,.3f}'.format,
        'ft_150': '{:,.3f}'.format,
        'ft_200': '{:,.3f}'.format,
        'ft_250': '{:,.3f}'.format,
        'gv_50': '{:,.3f}'.format,
        'gv_100': '{:,.3f}'.format,
        'gv_150': '{:,.3f}'.format,
        'gv_200': '{:,.3f}'.format,
        'gv_250': '{:,.3f}'.format,
})
)
# Out:
# <style  type="text/css" >
#     #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col1 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col2 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col3 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col4 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col5 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col6 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col7 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col8 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col9 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col10 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col11 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col12 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col13 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col14 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row0_col15 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col1 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col2 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col3 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col4 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col5 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col6 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col7 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col8 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col9 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col10 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col11 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col12 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col13 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col14 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row1_col15 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col1 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col2 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col3 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col4 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col5 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col6 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col7 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col8 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col9 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col10 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col11 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col12 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col13 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col14 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row2_col15 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col1 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col2 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col3 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col4 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col5 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col6 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col7 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col8 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col9 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col10 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col11 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col12 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col13 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col14 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row3_col15 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col1 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col2 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col3 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col4 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col5 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col6 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col7 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col8 {
#             color:  black;
#             background-color:  yellow;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col9 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col10 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col11 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col12 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931_11e9_a8f9_9cb6d08c5889row4_col13 {
#             color:  black;
#             : ;
#         }    #T_c593b33a_2931

# %%
# Concatenate the WE from Word2Vec (on Text8)
# and evaluate
# ----------------
MODELS_DIR = '../data/models/'

from gensim.models import KeyedVectors
import numpy as np
import os

all_models = dict()

# Load the WE
for dim in [100, 150, 200, 250]:
    tmp_path = os.path.join(MODELS_DIR, 'text8_wv{:d}dim.vec'.format(dim))
    
    if os.path.exists(tmp_path):
        print("Load embeddings from", 'text8_wv{:d}dim.vec'.format(dim))
        #gensim.models.keyedvectors.Word2VecKeyedVectors
        all_models[str(dim)] = KeyedVectors.load_word2vec_format(tmp_path)
# Out:
# 2019-02-05 11:40:01,258 : INFO : loading projection weights from ../data/models/text8_wv100dim.vec
# Load embeddings from text8_wv100dim.vec
# 2019-02-05 11:40:02,513 : INFO : loaded (17839, 100) matrix from ../data/models/text8_wv100dim.vec
# 2019-02-05 11:40:02,513 : INFO : loading projection weights from ../data/models/text8_wv150dim.vec
# Load embeddings from text8_wv150dim.vec
# 2019-02-05 11:40:04,262 : INFO : loaded (17839, 150) matrix from ../data/models/text8_wv150dim.vec
# 2019-02-05 11:40:04,263 : INFO : loading projection weights from ../data/models/text8_wv200dim.vec
# Load embeddings from text8_wv200dim.vec
# 2019-02-05 11:40:06,845 : INFO : loaded (17839, 200) matrix from ../data/models/text8_wv200dim.vec
# 2019-02-05 11:40:06,846 : INFO : loading projection weights from ../data/models/text8_wv250dim.vec
# Load embeddings from text8_wv250dim.vec
# 2019-02-05 11:40:09,631 : INFO : loaded (17839, 250) matrix from ../data/models/text8_wv250dim.vec

# %%
# Out:
# 17839

# %%
# Define the reference vocabulary for the concatenation
ref_vocab_model = all_models["100"]

# Get the ref_vocab with word in decreasing order of frequency
ref_vocab_dict = dict()
for item in ref_vocab_model.vocab:
    ref_vocab_dict[item] = ref_vocab_model.vocab[item].count
    
ref_vocab_dictSorted=dict(sorted(ref_vocab_dict.items(), key=lambda x: x[1],reverse=True))
ref_vocab_size = len(ref_vocab_dictSorted)
print(ref_vocab_size)
#print(ref_vocab_dictSorted)

# %%
# convert the word vectors into a numpy matrix
# follow the reference vocabulary to build the matrix
all_embedding_matrix = dict()

print("\n Converting...\n")
for dim in [100, 150, 200, 250]:
        
    print("{:d}".format(dim))
    tmp_vocab_size = len(all_models["{:d}".format(dim)].vocab)
    print("size vocab -->", tmp_vocab_size)
    
    if not tmp_vocab_size == len(ref_vocab_dict):
        print("--!!--> Difference voc. sizes ({:d} while ref. {:d})".format(tmp_vocab_size, ref_vocab_size))

    all_embedding_matrix["{:d}".format(dim)] = np.zeros((ref_vocab_size, dim))

    for str_w in ref_vocab_dictSorted:
        tmp_model = all_models["{:d}".format(dim)]
        tmp_embedding_vector = tmp_model[str_w]

        if tmp_embedding_vector is not None:
            all_embedding_matrix["{:d}".format(dim)][ref_vocab_dictSorted[str_w]-1] = tmp_embedding_vector
        else:
            print("{:s} embedding is None".format(str_w))

# %%
## convert the word vectors into a numpy matrix that is 
## suitable for insertion into our TensorFlow and Keras models
#all_embedding_matrix = dict()
#all_vocab = dict()
#
#for dim in [100, 150, 200, 250]:
#    print(dim)
#    tmp_vocab_size = len(all_models[str(dim)].vocab)
#    print("size vocab -->", tmp_vocab_size)
#
#    all_embedding_matrix[str(dim)] = np.zeros((tmp_vocab_size, dim))
#    all_vocab[str(dim)] = ['']*tmp_vocab_size
#    
#    for i in range(tmp_vocab_size):
#        tmp_model = all_models[str(dim)]
#        tmp_embedding_vector = tmp_model[tmp_model.index2word[i]]
#
#        if tmp_embedding_vector is not None:
#            all_embedding_matrix[str(dim)][i] = tmp_embedding_vector
#            all_vocab[str(dim)][i] = tmp_model.index2word[i]
#        else:
#            print(tmp_model.index2word[i], "None")
#
#all_vocab_ok = True
#dim = 100
#ref_vocab = all_vocab[str(dim)]
#print("\nLength ref_vocab", len(ref_vocab))
#print("Dim", dim, ref_vocab[0:10], "\n")
#
#for dim in [150, 200, 250]:
#    print("Dim", dim, all_vocab[str(dim)][0:10])
#    
#    if not all_vocab[str(dim)] == ref_vocab:
#        print("Not all vocabulary identical")
#        all_vocab_ok = False
#        break

# %%
# Concatenate the embeddings of all_models
#np.concatenate((a, b.T), axis=1)
all_embedding_concat_matrix = all_embedding_matrix[str(100)]

for dim in [150, 200, 250]:
    print(dim)
    all_embedding_concat_matrix = np.concatenate((all_embedding_concat_matrix, all_embedding_matrix[str(dim)]), axis = 1)
    
print(all_embedding_concat_matrix.shape)

# %%
# Write the concatenate the embeddings of all_models
concat_file = os.path.join(MODELS_DIR, 'concat_wv_models.vec')

if not os.path.isfile(concat_file):
    
    # Save vectors to output file
    with open(concat_file, 'w+') as f:
        f.write(str(all_embedding_concat_matrix.shape[0]) + " " + str(all_embedding_concat_matrix.shape[1]) + "\n")

        for word in ref_vocab_dictSorted:
            word_id = (ref_vocab_dictSorted[word]-1)
            f.write(word + " " + " ".join([str(value) for value in all_embedding_concat_matrix[word_id]]) + "\n")
        
    
    print('\nSaved concatenated embeddings model as concat_wv_models.vec')
else:
    print('\nUsing existing model file concat_wv_models.vec')

# %%
print('\nLoading embeddings of', concat_file)
concat_model = KeyedVectors.load_word2vec_format(concat_file)

# %%
concat_eval = list()
print('Accuracy:')
ret_sem_acc, ret_syn_acc = print_analogy_accuracy(concat_model, word_analogies_file)
concat_eval.append(ret_sem_acc); concat_eval.append(ret_syn_acc)
print('SimLex-999 similarity')
ret_corSpearman_simlex = print_similarity_accuracy(concat_model, simlex_file)
concat_eval.append(ret_corSpearman_simlex)
print("\nWordSim-353")
ret_corSpearman_word = print_similarity_accuracy(concat_model, wordsim_file)
concat_eval.append(ret_corSpearman_word)
print("\nWordSim-353 relatedness")
ret_corSpearman_word_rel = print_similarity_accuracy(concat_model, wordsim_rel_file)
concat_eval.append(ret_corSpearman_word_rel)
print("\nWordSim-353 similarity")
ret_corSpearman_word_sim = print_similarity_accuracy(concat_model, wordsim_sim_file)
concat_eval.append(ret_corSpearman_word_sim)
print("\nMEN similarity")
ret_corSpearman_men = print_similarity_accuracy(concat_model, men_file)
concat_eval.append(ret_corSpearman_men)
print("\nMturk similarity")
ret_corSpearman_men = print_similarity_accuracy(concat_model, mturk_file)
concat_eval.append(ret_corSpearman_men)

# %%
def eval_table_singleMethod_concat(eval_all):
    data_eval = [["QWsem", eval_all[0], 
                 ],

                 ["QWsyn", eval_all[1], 
                 ],

                 ["CorSPear_simlex", eval_all[2], 
                 ],

                 ["CorSPear_word", eval_all[3], 
                 ],

                 ["CorSPear_word_rel", eval_all[4], 
                 ],

                 ["CorSPear_word_sim", eval_all[5], 
                 ],

                 ["CorSPear_men", eval_all[6], 
                 ]
                ]


    return data_eval

colnames = ["evals", "wv_dim_concat", 
               ]

# cp_name = 'brown'
cp_name = 'text8'
res_eval = eval_table_singleMethod_concat(concat_eval)
df = pd.DataFrame(res_eval, columns = colnames)

(df.style
   .applymap(color_negative_red, subset = pd.IndexSlice[:, colnames[1:len(colnames)]])
   .apply(highlight_max, axis= 1, subset = pd.IndexSlice[0:6, colnames[1:len(colnames)]])
   .format({
        'wv_dim_concat': '{:,.3f}'.format,
})
)

# %%
# Concatenate the WE from fastText (on Text8)
# and evaluate
# ----------------
from gensim.models import KeyedVectors
import numpy as np
import os

all_models = dict()

# Load the WE
for dim in [100, 150, 200, 250]:
    tmp_path = os.path.join(MODELS_DIR, 'text8_ft{:d}dim.vec'.format(dim))
    
    if os.path.exists(tmp_path):
        print("Load embeddings from", 'text8_ft{:d}dim.vec'.format(dim))
        #gensim.models.keyedvectors.Word2VecKeyedVectors
        all_models[str(dim)] = KeyedVectors.load_word2vec_format(tmp_path)

# %%
# Define the reference vocabulary for the concatenation
ref_vocab_model = all_models["100"]

# Get the ref_vocab with word in decreasing order of frequency
ref_vocab_dict = dict()
for item in ref_vocab_model.vocab:
    ref_vocab_dict[item] = ref_vocab_model.vocab[item].count
    
ref_vocab_dictSorted=dict(sorted(ref_vocab_dict.items(), key=lambda x: x[1],reverse=True))
ref_vocab_size = len(ref_vocab_dictSorted)
print(ref_vocab_size)
#print(ref_vocab_dictSorted)

# %%
# convert the word vectors into a numpy matrix
# follow the reference vocabulary to build the matrix
all_embedding_matrix = dict()

print("\n Converting...\n")
for dim in [50, 100, 150, 200, 250]:
        
    print("{:d}".format(dim))
    tmp_vocab_size = len(all_models["{:d}".format(dim)].vocab)
    print("size vocab -->", tmp_vocab_size)
    
    if not tmp_vocab_size == len(ref_vocab_dict):
        print("--!!--> Difference voc. sizes ({:d} while ref. {:d})".format(tmp_vocab_size, ref_vocab_size))

    all_embedding_matrix["{:d}".format(dim)] = np.zeros((ref_vocab_size, dim))

    for str_w in ref_vocab_dictSorted:
        tmp_model = all_models["{:d}".format(dim)]
        tmp_embedding_vector = tmp_model[str_w]

        if tmp_embedding_vector is not None:
            all_embedding_matrix["{:d}".format(dim)][ref_vocab_dictSorted[str_w]-1] = tmp_embedding_vector
        else:
            print("{:s} embedding is None".format(str_w))

# %%
## convert the word vectors into a numpy matrix that is 
## suitable for insertion into our TensorFlow and Keras models
#all_embedding_matrix = dict()
#all_vocab = dict()
#
#for dim in [100, 150, 200, 250]:
#    print(dim)
#    tmp_vocab_size = len(all_models[str(dim)].vocab)
#    print("size vocab -->", tmp_vocab_size)
#
#    all_embedding_matrix[str(dim)] = np.zeros((tmp_vocab_size, dim))
#    all_vocab[str(dim)] = ['']*tmp_vocab_size
#    
#    for i in range(tmp_vocab_size):
#        tmp_model = all_models[str(dim)]
#        tmp_embedding_vector = tmp_model[tmp_model.index2word[i]]
#
#        if tmp_embedding_vector is not None:
#            all_embedding_matrix[str(dim)][i] = tmp_embedding_vector
#            all_vocab[str(dim)][i] = tmp_model.index2word[i]
#        else:
#            print(tmp_model.index2word[i], "None")
#
#all_vocab_ok = True
#dim = 100
#ref_vocab = all_vocab[str(dim)]
#print("\nLength ref_vocab", len(ref_vocab))
#print("Dim", dim, ref_vocab[0:10], "\n")
#
#for dim in [150, 200, 250]:
#    print("Dim", dim, all_vocab[str(dim)][0:10])
#    
#    if not all_vocab[str(dim)] == ref_vocab:
#        print("Not all vocabulary identical")
#        all_vocab_ok = False
#        break

# %%
# Concatenate the embeddings of all_models
#np.concatenate((a, b.T), axis=1)
all_embedding_concat_matrix = all_embedding_matrix[str(100)]

for dim in [150, 200, 250]:
    print(dim)
    all_embedding_concat_matrix = np.concatenate((all_embedding_concat_matrix, all_embedding_matrix[str(dim)]), axis = 1)
    
print(all_embedding_concat_matrix.shape)

# %%
# Write the concatenate the embeddings of all_models
concat_file = os.path.join(MODELS_DIR, 'concat_ft_models.vec')

if not os.path.isfile(concat_file):
    
    # Save vectors to output file
    with open(concat_file, 'w+') as f:
        f.write(str(all_embedding_concat_matrix.shape[0]) + " " + str(all_embedding_concat_matrix.shape[1]) + "\n")

        for word in ref_vocab_dictSorted:
            word_id = (ref_vocab_dictSorted[word]-1)
            f.write(word + " " + " ".join([str(value) for value in all_embedding_concat_matrix[word_id]]) + "\n")
        
    
    print('\nSaved concatenated embeddings model as concat_ft_models.vec')
else:
    print('\nUsing existing model file concat_ft_models.vec')

# %%
print('\nLoading embeddings of', concat_file)
concat_model = KeyedVectors.load_word2vec_format(concat_file)

# %%
concat_eval = list()
print('Accuracy:')
ret_sem_acc, ret_syn_acc = print_analogy_accuracy(concat_model, word_analogies_file)
concat_eval.append(ret_sem_acc); concat_eval.append(ret_syn_acc)
print('SimLex-999 similarity')
ret_corSpearman_simlex = print_similarity_accuracy(concat_model, simlex_file)
concat_eval.append(ret_corSpearman_simlex)
print("\nWordSim-353")
ret_corSpearman_word = print_similarity_accuracy(concat_model, wordsim_file)
concat_eval.append(ret_corSpearman_word)
print("\nWordSim-353 relatedness")
ret_corSpearman_word_rel = print_similarity_accuracy(concat_model, wordsim_rel_file)
concat_eval.append(ret_corSpearman_word_rel)
print("\nWordSim-353 similarity")
ret_corSpearman_word_sim = print_similarity_accuracy(concat_model, wordsim_sim_file)
concat_eval.append(ret_corSpearman_word_sim)
print("\nMEN similarity")
ret_corSpearman_men = print_similarity_accuracy(concat_model, men_file)
concat_eval.append(ret_corSpearman_men)
print("\nMturk similarity")
ret_corSpearman_men = print_similarity_accuracy(concat_model, mturk_file)
concat_eval.append(ret_corSpearman_men)

# %%
def eval_table_singleMethod_concat(eval_all):
    data_eval = [["QWsem", eval_all[0], 
                 ],

                 ["QWsyn", eval_all[1], 
                 ],

                 ["CorSPear_simlex", eval_all[2], 
                 ],

                 ["CorSPear_word", eval_all[3], 
                 ],

                 ["CorSPear_word_rel", eval_all[4], 
                 ],

                 ["CorSPear_word_sim", eval_all[5], 
                 ],

                 ["CorSPear_men", eval_all[6], 
                 ]
                ]


    return data_eval

colnames = ["evals", "ft_dim_concat", 
               ]

# cp_name = 'brown'
cp_name = 'text8'
res_eval = eval_table_singleMethod_concat(concat_eval)
df = pd.DataFrame(res_eval, columns = colnames)

(df.style
   .applymap(color_negative_red, subset = pd.IndexSlice[:, colnames[1:len(colnames)]])
   .apply(highlight_max, axis= 1, subset = pd.IndexSlice[0:6, colnames[1:len(colnames)]])
   .format({
        'ft_dim_concat': '{:,.3f}'.format,
})
)

# %%
# Concatenate the WE from word2vec AND fastText (on Text8)
# and evaluate
# ----------------
from gensim.models import KeyedVectors
import numpy as np
import os

all_models = dict()
all_dim = [100, 150, 200, 250]
all_meth_dim = list(zip(['wv']*len(all_dim)+['ft']*len(all_dim), all_dim*2))

# Load the WE
for meth, dim in all_meth_dim:
    
    tmp_path = os.path.join(MODELS_DIR, 'text8_{:s}{:d}dim.vec'.format(meth, dim))
    
    if os.path.exists(tmp_path):
        print("Load embeddings from", 'text8_{:s}{:d}dim.vec'.format(meth, dim))
        #gensim.models.keyedvectors.Word2VecKeyedVectors
        all_models["{:s}_{:d}".format(meth, dim)] = KeyedVectors.load_word2vec_format(tmp_path)

# %%
ref_vocab_model = all_models["wv_100"]

# Get the ref_vocab with word in decreasing order of frequency
ref_vocab_dict = dict()
for item in ref_vocab_model.vocab:
    ref_vocab_dict[item] = ref_vocab_model.vocab[item].count
    
ref_vocab_dictSorted=dict(sorted(ref_vocab_dict.items(), key=lambda x: x[1],reverse=True))
ref_vocab_size = len(ref_vocab_dictSorted)

print(len(ref_vocab_dictSorted))

# %%
# convert the word vectors into a numpy matrix
# follow the reference vocabulary to build the matrix
all_embedding_matrix = dict()

print("\n Converting...\n")
for meth, dim in all_meth_dim:
        
    print("{:s}_{:d}".format(meth, dim))
    tmp_vocab_size = len(all_models["{:s}_{:d}".format(meth, dim)].vocab)
    print("size vocab -->", tmp_vocab_size)
    
    if not tmp_vocab_size == len(ref_vocab_dict):
        print("--!!--> Difference voc. sizes ({:d} while ref. {:d})".format(tmp_vocab_size, ref_vocab_size))

    all_embedding_matrix["{:s}_{:d}".format(meth, dim)] = np.zeros((ref_vocab_size, dim))

    for str_w in ref_vocab_dictSorted:
        tmp_model = all_models["{:s}_{:d}".format(meth, dim)]
        #tmp_embedding_vector = tmp_model[tmp_model.index2word[i]]
        tmp_embedding_vector = tmp_model[str_w]

        if tmp_embedding_vector is not None:
            all_embedding_matrix["{:s}_{:d}".format(meth, dim)][ref_vocab_dictSorted[str_w]-1] = tmp_embedding_vector
        else:
            print("{:s} embedding is None".foramt(str_w))

# %%
# Concatenate the embeddings of all_models
#np.concatenate((a, b.T), axis=1)
all_embedding_concat_matrix = all_embedding_matrix["wv_100"]

for meth, dim in all_meth_dim:
    print("{:s}_{:d}".format(meth, dim))
    all_embedding_concat_matrix = np.concatenate((all_embedding_concat_matrix, all_embedding_matrix["{:s}_{:d}".format(meth, dim)]), axis = 1)
    
print(all_embedding_concat_matrix.shape)

# %%
# Write the concatenate the embeddings of all_models
concat_file = os.path.join(MODELS_DIR, 'concat_wv_ft_models.vec')

if not os.path.isfile(concat_file):
    
    # Save vectors to output file
    with open(concat_file, 'w+') as f:
        f.write(str(all_embedding_concat_matrix.shape[0]) + " " + str(all_embedding_concat_matrix.shape[1]) + "\n")

        for word in ref_vocab_dictSorted:
            word_id = (ref_vocab_dictSorted[word]-1)
            f.write(word + " " + " ".join([str(value) for value in all_embedding_concat_matrix[word_id]]) + "\n")
        
    
    print('\nSaved concatenated embeddings model as concat_wv_ft_models.vec')
else:
    print('\nUsing existing model file concat_wv_ft_models.vec')

# %%
print('\nLoading embeddings of', concat_file)
concat_model = KeyedVectors.load_word2vec_format(concat_file)

# %%
concat_eval = list()
print('Accuracy:')
ret_sem_acc, ret_syn_acc = print_analogy_accuracy(concat_model, word_analogies_file)
concat_eval.append(ret_sem_acc); concat_eval.append(ret_syn_acc)
print('SimLex-999 similarity')
ret_corSpearman_simlex = print_similarity_accuracy(concat_model, simlex_file)
concat_eval.append(ret_corSpearman_simlex)
print("\nWordSim-353")
ret_corSpearman_word = print_similarity_accuracy(concat_model, wordsim_file)
concat_eval.append(ret_corSpearman_word)
print("\nWordSim-353 relatedness")
ret_corSpearman_word_rel = print_similarity_accuracy(concat_model, wordsim_rel_file)
concat_eval.append(ret_corSpearman_word_rel)
print("\nWordSim-353 similarity")
ret_corSpearman_word_sim = print_similarity_accuracy(concat_model, wordsim_sim_file)
concat_eval.append(ret_corSpearman_word_sim)
print("\nMEN similarity")
ret_corSpearman_men = print_similarity_accuracy(concat_model, men_file)
concat_eval.append(ret_corSpearman_men)
print("\nMturk similarity")
ret_corSpearman_men = print_similarity_accuracy(concat_model, mturk_file)
concat_eval.append(ret_corSpearman_men)

# %%
def eval_table_singleMethod_concat(eval_all):
    data_eval = [["QWsem", eval_all[0], 
                 ],

                 ["QWsyn", eval_all[1], 
                 ],

                 ["CorSPear_simlex", eval_all[2], 
                 ],

                 ["CorSPear_word", eval_all[3], 
                 ],

                 ["CorSPear_word_rel", eval_all[4], 
                 ],

                 ["CorSPear_word_sim", eval_all[5], 
                 ],

                 ["CorSPear_men", eval_all[6], 
                 ]
                ]


    return data_eval

colnames = ["evals", "wv_ft_dim_concat", 
               ]

# cp_name = 'brown'
cp_name = 'text8'
res_eval = eval_table_singleMethod_concat(concat_eval)
df = pd.DataFrame(res_eval, columns = colnames)

(df.style
   .applymap(color_negative_red, subset = pd.IndexSlice[:, colnames[1:len(colnames)]])
   .apply(highlight_max, axis= 1, subset = pd.IndexSlice[0:6, colnames[1:len(colnames)]])
   .format({
        'wv_ft_dim_concat': '{:,.3f}'.format,
})
)
